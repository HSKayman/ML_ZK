# %%
import pandas as pd

# %%
df = pd.read_csv("gradient_swap_attack_optimized_2026-02-22_21-10-31.csv")

# %%
df.columns
# Out:
# Index(['input_id', 'allowed_neurons', 'special_node_idx', 'special_node_score',
#        'baseline_success', 'baseline_num_neurons', 'baseline_epsilon',
#        'baseline_special_used', 'baseline_total_magnitude',
#        'baseline_max_perturbation', 'baseline_l2_distance',
#        'baseline_cosine_distance', 'baseline_kl_divergence',
#        'baseline_js_divergence', 'baseline_final_top1_word',
#        'baseline_final_top1_index', 'baseline_final_top1_logit',
#        'baseline_final_top1_softmax', 'baseline_final_top2_word',
#        'baseline_final_top2_index', 'baseline_final_top2_logit',
#        'baseline_final_top2_softmax', 'baseline_final_top3_word',
#        'baseline_final_top3_index', 'baseline_final_top3_logit',
#        'baseline_final_top3_softmax', 'constrained_success',
#        'constrained_num_neurons', 'constrained_epsilon',
#        'constrained_special_avoided', 'constrained_total_magnitude',
# ...

# %%
df_new = df[df["constrained_final_top1_index"] != df["orig_top1_index"]]

# %%
df_new.to_csv("gradient_swap_attack_optimized_2026-02-22_21-10-31_only_changed_top1_constrained.csv", index=False)
