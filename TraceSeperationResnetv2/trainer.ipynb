# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import DataLoader
from torchvision import datasets
import numpy as np
import random
from model_structure import get_preprocessing_transforms, train_model, evaluate_model, get_resnet_model, get_squ_model

# %%
seed = 441
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
MODEL_NUMBER = 2
BATCH_SIZE = 32
LEARNING_RATE = 0.001
NUM_EPOCHS = 50
INPUT_SIZE = 224
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Get transforms
train_transform, val_transform = get_preprocessing_transforms(INPUT_SIZE)

# %%
# master file path 
master_file_path = '.'
# Set data set directory
train_dir = f'{master_file_path}/data4model_{MODEL_NUMBER}/train/'
val_dir = f'{master_file_path}/data4model_{MODEL_NUMBER}/test/'

# %%
# Create datasets
train_dataset = datasets.ImageFolder(
        root=train_dir,
        transform=train_transform
    )
    
val_dataset = datasets.ImageFolder(
        root=val_dir,
        transform=val_transform
    )

# %%
# Create data loaders
train_loader = DataLoader(
    train_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True, 
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False, 
    num_workers=4,
    pin_memory=True
)

# %%
model = get_resnet_model(2).to(DEVICE)
criterion =  nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
model.eval()
# Out:
# /home/hsk/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hsk/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
summary(model, (3, INPUT_SIZE, INPUT_SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                    [-1, 2]           1,026
# ================================================================
# Total params: 11,177,538
# Trainable params: 11,177,538
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.64
# Estimated Total Size (MB): 106.00
# ----------------------------------------------------------------

# %%
tracker = train_model(model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS, DEVICE, MODEL_NUMBER)
# Out:
# Epoch [1/50]
# Training Loss: 0.2309, Validation Loss: 1.9616
# Training Acc: 0.9097, Validation Acc: 0.5200
# Training F1: 0.9104, Validation F1: 0.0769
# Epoch [2/50]
# Training Loss: 0.1315, Validation Loss: 0.8656
# Training Acc: 0.9473, Validation Acc: 0.7500
# Training F1: 0.9476, Validation F1: 0.6753
# Epoch [3/50]
# Training Loss: 0.1085, Validation Loss: 0.5396
# Training Acc: 0.9640, Validation Acc: 0.8150
# Training F1: 0.9642, Validation F1: 0.7836
# Epoch [4/50]
# Training Loss: 0.0926, Validation Loss: 0.4002
# Training Acc: 0.9633, Validation Acc: 0.8350
# Training F1: 0.9635, Validation F1: 0.8114
# Epoch [5/50]
# Training Loss: 0.0956, Validation Loss: 0.6180
# Training Acc: 0.9633, Validation Acc: 0.8050
# Training F1: 0.9635, Validation F1: 0.7821
# Epoch [6/50]
# Training Loss: 0.0733, Validation Loss: 1.9492
# Training Acc: 0.9743, Validation Acc: 0.5950
# Training F1: 0.9744, Validation F1: 0.3306
# Epoch [7/50]
# Training Loss: 0.0930, Validation Loss: 0.6528
# Training Acc: 0.9680, Validation Acc: 0.8050
# Training F1: 0.9681, Validation F1: 0.7578
# Epoch [8/50]
# Training Loss: 0.0792, Validation Loss: 1.0475
# Training Acc: 0.9730, Validation Acc: 0.7550
# Training F1: 0.9730, Validation F1: 0.6755
# Epoch [9/50]
# Training Loss: 0.0627, Validation Loss: 0.3583
# Training Acc: 0.9810, Validation Acc: 0.8800
# Training F1: 0.9811, Validation F1: 0.8812
# Epoch [10/50]
# Training Loss: 0.0540, Validation Loss: 0.8806
# Training Acc: 0.9787, Validation Acc: 0.7350
# Training F1: 0.9787, Validation F1: 0.6395
# Epoch [11/50]
# Training Loss: 0.0513, Validation Loss: 0.8373
# Training Acc: 0.9803, Validation Acc: 0.8200
# Training F1: 0.9803, Validation F1: 0.7931
# Epoch [12/50]
# Training Loss: 0.0501, Validation Loss: 1.0362
# Training Acc: 0.9813, Validation Acc: 0.7400
# Training F1: 0.9813, Validation F1: 0.6486
# Epoch [13/50]
# Training Loss: 0.0619, Validation Loss: 0.7219
# Training Acc: 0.9763, Validation Acc: 0.7850
# Training F1: 0.9764, Validation F1: 0.7329
# Epoch [14/50]
# Training Loss: 0.0333, Validation Loss: 0.4637
# Training Acc: 0.9870, Validation Acc: 0.9050
# Training F1: 0.9870, Validation F1: 0.8962
# Epoch [15/50]
# Training Loss: 0.0416, Validation Loss: 0.5956
# Training Acc: 0.9857, Validation Acc: 0.8000
# Training F1: 0.9857, Validation F1: 0.7561
# Epoch [16/50]
# Training Loss: 0.0442, Validation Loss: 2.4645
# Training Acc: 0.9857, Validation Acc: 0.6350
# Training F1: 0.9857, Validation F1: 0.4341
# Epoch [17/50]
# Training Loss: 0.0526, Validation Loss: 1.7812
# Training Acc: 0.9810, Validation Acc: 0.6850
# Training F1: 0.9810, Validation F1: 0.5401
# Epoch [18/50]
# Training Loss: 0.0329, Validation Loss: 0.7196
# Training Acc: 0.9900, Validation Acc: 0.8200
# Training F1: 0.9900, Validation F1: 0.7805
# Epoch [19/50]
# Training Loss: 0.0429, Validation Loss: 1.1114
# Training Acc: 0.9863, Validation Acc: 0.7950
# Training F1: 0.9863, Validation F1: 0.7453
# Epoch [20/50]
# Training Loss: 0.0451, Validation Loss: 0.5097
# Training Acc: 0.9837, Validation Acc: 0.8450
# Training F1: 0.9837, Validation F1: 0.8249
# Epoch [21/50]
# Training Loss: 0.0287, Validation Loss: 1.3627
# Training Acc: 0.9880, Validation Acc: 0.7900
# Training F1: 0.9880, Validation F1: 0.7407
# Epoch [22/50]
# Training Loss: 0.0534, Validation Loss: 0.9119
# Training Acc: 0.9793, Validation Acc: 0.7200
# Training F1: 0.9793, Validation F1: 0.6111
# Epoch [23/50]
# Training Loss: 0.0424, Validation Loss: 0.3147
# Training Acc: 0.9840, Validation Acc: 0.8850
# Training F1: 0.9840, Validation F1: 0.8729
# Epoch [24/50]
# Training Loss: 0.0179, Validation Loss: 1.3225
# Training Acc: 0.9933, Validation Acc: 0.7600
# Training F1: 0.9933, Validation F1: 0.6923
# Epoch [25/50]
# Training Loss: 0.0383, Validation Loss: 1.8754
# Training Acc: 0.9857, Validation Acc: 0.6900
# Training F1: 0.9857, Validation F1: 0.5921
# Epoch [26/50]
# Training Loss: 0.0434, Validation Loss: 0.5340
# Training Acc: 0.9840, Validation Acc: 0.8250
# Training F1: 0.9840, Validation F1: 0.7953
# Epoch [27/50]
# Training Loss: 0.0155, Validation Loss: 0.5112
# Training Acc: 0.9937, Validation Acc: 0.8650
# Training F1: 0.9937, Validation F1: 0.8508
# Epoch [28/50]
# Training Loss: 0.0342, Validation Loss: 0.6598
# Training Acc: 0.9900, Validation Acc: 0.8800
# Training F1: 0.9900, Validation F1: 0.8696
# Epoch [29/50]
# Training Loss: 0.0390, Validation Loss: 1.0928
# Training Acc: 0.9857, Validation Acc: 0.7750
# Training F1: 0.9857, Validation F1: 0.7170
# Epoch [30/50]
# Training Loss: 0.0290, Validation Loss: 0.5918
# Training Acc: 0.9883, Validation Acc: 0.8550
# Training F1: 0.9883, Validation F1: 0.8324
# Epoch [31/50]
# Training Loss: 0.0304, Validation Loss: 0.5366
# Training Acc: 0.9900, Validation Acc: 0.8700
# Training F1: 0.9900, Validation F1: 0.8556
# Epoch [32/50]
# Training Loss: 0.0182, Validation Loss: 1.0119
# Training Acc: 0.9927, Validation Acc: 0.8050
# Training F1: 0.9927, Validation F1: 0.7665
# Epoch [33/50]
# Training Loss: 0.0424, Validation Loss: 0.2825
# Training Acc: 0.9860, Validation Acc: 0.9100
# Training F1: 0.9860, Validation F1: 0.9062
# Epoch [34/50]
# Training Loss: 0.0394, Validation Loss: 0.4946
# Training Acc: 0.9880, Validation Acc: 0.8900
# Training F1: 0.9880, Validation F1: 0.8804
# Epoch [35/50]
# Training Loss: 0.0297, Validation Loss: 0.8194
# Training Acc: 0.9887, Validation Acc: 0.8150
# Training F1: 0.9887, Validation F1: 0.7784
# Epoch [36/50]
# Training Loss: 0.0317, Validation Loss: 0.6426
# Training Acc: 0.9890, Validation Acc: 0.8600
# Training F1: 0.9890, Validation F1: 0.8444
# Epoch [37/50]
# Training Loss: 0.0278, Validation Loss: 0.5547
# Training Acc: 0.9880, Validation Acc: 0.8550
# Training F1: 0.9880, Validation F1: 0.8343
# Epoch [38/50]
# Training Loss: 0.0130, Validation Loss: 2.4209
# Training Acc: 0.9953, Validation Acc: 0.7400
# Training F1: 0.9953, Validation F1: 0.6579
# Epoch [39/50]
# Training Loss: 0.0378, Validation Loss: 0.6311
# Training Acc: 0.9887, Validation Acc: 0.8550
# Training F1: 0.9887, Validation F1: 0.8324
# Epoch [40/50]
# Training Loss: 0.0284, Validation Loss: 2.1515
# Training Acc: 0.9907, Validation Acc: 0.6300
# Training F1: 0.9907, Validation F1: 0.4127
# Epoch [41/50]
# Training Loss: 0.0335, Validation Loss: 0.7408
# Training Acc: 0.9887, Validation Acc: 0.8550
# Training F1: 0.9887, Validation F1: 0.8343
# Epoch [42/50]
# Training Loss: 0.0337, Validation Loss: 1.2452
# Training Acc: 0.9890, Validation Acc: 0.7650
# Training F1: 0.9890, Validation F1: 0.6968
# Epoch [43/50]
# Training Loss: 0.0236, Validation Loss: 2.2035
# Training Acc: 0.9923, Validation Acc: 0.6000
# Training F1: 0.9923, Validation F1: 0.3333
# Epoch [44/50]
# Training Loss: 0.0306, Validation Loss: 0.9244
# Training Acc: 0.9903, Validation Acc: 0.8500
# Training F1: 0.9903, Validation F1: 0.8276
# Epoch [45/50]
# Training Loss: 0.0305, Validation Loss: 0.8616
# Training Acc: 0.9903, Validation Acc: 0.8500
# Training F1: 0.9903, Validation F1: 0.8235
# Epoch [46/50]
# Training Loss: 0.0246, Validation Loss: 1.0408
# Training Acc: 0.9920, Validation Acc: 0.7950
# Training F1: 0.9920, Validation F1: 0.7485
# Epoch [47/50]
# Training Loss: 0.0179, Validation Loss: 1.1819
# Training Acc: 0.9937, Validation Acc: 0.8150
# Training F1: 0.9937, Validation F1: 0.7784
# Epoch [48/50]
# Training Loss: 0.0282, Validation Loss: 0.9686
# Training Acc: 0.9893, Validation Acc: 0.8100
# Training F1: 0.9893, Validation F1: 0.7738
# Epoch [49/50]
# Training Loss: 0.0158, Validation Loss: 1.8532
# Training Acc: 0.9953, Validation Acc: 0.7700
# Training F1: 0.9953, Validation F1: 0.7051
# Epoch [50/50]
# Training Loss: 0.0099, Validation Loss: 1.2070
# Training Acc: 0.9967, Validation Acc: 0.8200
# Training F1: 0.9967, Validation F1: 0.7857
