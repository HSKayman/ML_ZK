# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import DataLoader
import seaborn as sns
import matplotlib.pyplot as plt
from torchvision import datasets
import numpy as np
import pandas as pd
import os
from model_structure import get_preprocessing_transforms,get_resnet_model,BCNN, train_model, evaluate_model

# %%
INPUT_SIZE = 224
BATCH_SIZE = 32
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Get transforms
train_transform, val_transform = get_preprocessing_transforms(INPUT_SIZE)

test_data_1_dir = 'data4model_1/test/'
test_data_2_dir = 'data4model_2/test/'
train_data_1_dir = 'data4model_1/train/'
train_data_2_dir = 'data4model_2/train/'

# Load data set
dataset_test_1 = datasets.ImageFolder(test_data_1_dir,transform=val_transform)
dataset_train_1 = datasets.ImageFolder(train_data_1_dir,transform=val_transform)
dataset_test_2 = datasets.ImageFolder(test_data_2_dir,transform=val_transform)
dataset_train_2 = datasets.ImageFolder(train_data_2_dir,transform=val_transform)
additional_set = datasets.ImageFolder('data4model_1/for_extra_test/',transform=val_transform)



additional_loader = DataLoader(additional_set, shuffle=False, batch_size=BATCH_SIZE)
test_loader_1 = DataLoader(dataset_test_1, shuffle=False, batch_size=BATCH_SIZE)
train_loader_1 = DataLoader(dataset_train_1, shuffle=False, batch_size=BATCH_SIZE)
test_loader_2 = DataLoader(dataset_test_2, shuffle=False, batch_size=BATCH_SIZE)
train_loader_2 = DataLoader(dataset_train_2, shuffle=False, batch_size=BATCH_SIZE)

dataSets =  {"Model_1:Train": train_loader_1,
        "Model_1:Test": test_loader_1,
        "Model_2:Train": train_loader_2,
        "Model_2:Test": test_loader_2,
        "Model_1:additional_set": additional_loader
        }

# %%
# model_1_dir = 'my_models/best_model_1.pth'
# model_2_dir = 'my_models/best_model_2.pth'
model_info = "pretrained" # "my" or "new"
model_1_dir = 'best_model_1.pth'
model_2_dir = 'best_model_2.pth'

# %%
# Load the model
# model_1 = BCNN().to(DEVICE)
model_1 = get_resnet_model(2).to(DEVICE)
weights = torch.load(model_1_dir, map_location=torch.device(DEVICE))
model_1.load_state_dict(weights)
model_1.eval()

#model_2 = BCNN().to(DEVICE)
model_2 = get_resnet_model(2).to(DEVICE)
weights = torch.load(model_2_dir, map_location=torch.device(DEVICE))
model_2.load_state_dict(weights)
model_2.eval()
# Out:
# C:\Users\hskay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\hskay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\hskay\AppData\Local\Temp\ipykernel_8448\1659288269.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   weights = torch.load(model_1_dir, map_location=torch.device(DEVICE))
# C:\Users\hskay\AppData\Local\Temp\ipykernel_8448\1659288269.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   weights = torch.load(model_2_dir, map_location=torch.device(DEVICE))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
for key in dataSets:
    print(key)
    if "Model_1" in key:
        model = model_1
    else:
        model = model_2
    
    results = evaluate_model(model.to(DEVICE), dataSets[key], DEVICE)
    print("Accuracy: ", results[0])
    print("F1 Score: ", results[1])
    print("confusion Matrix: \n",results[3])
    print("\n")
# Out:
# Model_1:Train
# Accuracy:  0.9283333333333333
# F1 Score:  0.9271926854046733
# confusion Matrix:
#  [[1416   84]
#  [ 131 1369]]
#
#
# Model_1:Test
# Accuracy:  0.87
# F1 Score:  0.8617021276595744
# confusion Matrix:
#  [[93  7]
#  [19 81]]
#
#
# Model_2:Train
# Accuracy:  0.9436666666666667
# F1 Score:  0.9452188006482982
# confusion Matrix:
#  [[1373  127]
#  [  42 1458]]
#
#
# Model_2:Test
# Accuracy:  0.89
# F1 Score:  0.8981481481481481
# confusion Matrix:
#  [[81 19]
#  [ 3 97]]
#
#
# Model_1:additional_set
# Accuracy:  0.723422860712055
# F1 Score:  0.7165172855313701
# confusion Matrix:
#  [[2993 1007]
#  [1207 2798]]

# %%
K_ROUND = 50  # Number of rounds to monitor
activation_values = {"Model_1":{},
                     "Model_2":{}}

# %%
activation_values = {"Model_1": {}, "Model_2": {}}

def register_hooks(model, model_name):
    activation_values[model_name] = {}
    hooks = []
    
    def get_hook(name):
        def hook(module, input, output):
            # Store input, output, weights and biases
            activation_values[model_name][name] = {
                'input': input[0].detach(),
                'output': output.detach(),
                'weight': module.weight.detach() if hasattr(module, 'weight') else None,
                'bias': module.bias.detach() if hasattr(module, 'bias') and module.bias is not None else None,
            }
            if isinstance(module, nn.Conv2d):
                activation_values[model_name][name]['conv_params'] = {
                    'kernel_size': module.kernel_size[0] if isinstance(module.kernel_size, tuple) else module.kernel_size,
                    'padding': module.padding[0] if isinstance(module.padding, tuple) else module.padding,
                    'stride': module.stride[0] if isinstance(module.stride, tuple) else module.stride,
                    'dilation': module.dilation[0] if isinstance(module.dilation, tuple) else module.dilation
                }
        return hook
    
    for name, module in model.named_modules():
        if isinstance(module, (nn.Conv2d, nn.Linear)):
            hooks.append(module.register_forward_hook(get_hook(name)))
    
    return hooks

# %%
def select_random_neuron_indices(activations, n_neurons=1):
    indices = {}
    
    for layer_name, layer_data in activations.items():
        # skipping if layer without weight
        if not isinstance(layer_data, dict) or 'output' not in layer_data:
            continue
            
        # activation output and flatten it
        activation = layer_data['output']
        flattened = activation.view(activation.shape[0], -1)
        
        # positive (activated) indices
        positive_indices = np.where(flattened.cpu().numpy().squeeze() > 0)[0]
        
        # skipping if no activated neurons
        if len(positive_indices) == 0:
            continue
            
        # random neurons from activated ones
        selected_indices = np.random.choice(
            positive_indices,
            size=min(n_neurons, len(positive_indices)),
            replace=False
        )
        
        # storing selected indices
        indices[layer_name] = {
            'neuron_idx': selected_indices,
            'all_activated_indices': positive_indices,
            'original_shape': activation.shape
        }
    
    return indices

# %%
def compare_model_activations(model1_activations, model2_activations, selected_indices):
    comparison_results = {}
    
    for layer_name, indices_info in selected_indices.items():
        if layer_name not in model1_activations or layer_name not in model2_activations:
            continue
        
        data1 = model1_activations[layer_name]
        data2 = model2_activations[layer_name]
        
        if not isinstance(data1, dict) or not isinstance(data2, dict):
            continue
        
        selected_indices = indices_info['neuron_idx']
        original_shape = indices_info.get('original_shape', data1['output'].shape)
        
        # get inputs, weights, biases, and stored outputs
        input1 = data1['input']
        weights1 = data1['weight']
        bias1 = data1.get('bias')
        weights2 = data2['weight']
        bias2 = data2.get('bias')
        stored_output1 = data1['output']
    
        layer_results = {
            'neuron_comparisons': [],
            'model1_verification_errors': [],
            'cross_model_differences': []
        }
        
        for idx in selected_indices:
            if len(weights1.shape) == 4:
                # dimensions: batch_size, channels, height, width
                batch_size, channels, height, width = original_shape
                
                # converting flat idx to corresponding coordinates
                channel = idx // (height * width)
                pos_in_channel = idx % (height * width)
                h_idx = pos_in_channel // width
                w_idx = pos_in_channel % width
                
                # remove try it is for debugging
                if channel >= stored_output1.shape[1]:
                    continue
                
                # get stored activation for this position
                stored_activation = stored_output1[0, channel, h_idx, w_idx].item()
                
                
                ####################################
                # check if it is correct because of hyperparameters of conv.
                ####################################
                # get convolution parameters
                kernel_size = weights1.shape[2]
                padding = kernel_size // 2  # symmetric padding
                
                # get input patch that corresponds to this position
                if '1'=='2':#DEBUG
                    #DEBUG
                    in_h_start = max(0, h_idx - padding) #DEBUG
                    in_w_start = max(0, w_idx - padding)#DEBUG
                    in_h_end = min(input1.shape[2], h_idx + kernel_size - padding)#DEBUG
                    in_w_end = min(input1.shape[3], w_idx + kernel_size - padding)#DEBUG
                    input_patch = input1[0, :, in_h_start:in_h_end, in_w_start:in_w_end]#DEBUG
                else:
                    conv_params = data1.get('conv_params', {
                        'kernel_size': 3, 
                        'padding': 1,
                        'stride': 1,
                        'dilation': 1
                    })
                    
                    kernel_size = conv_params['kernel_size']
                    padding = conv_params['padding']
                    stride = conv_params['stride']
                    dilation = conv_params['dilation']
                    
                    # Calculate input patch position
                    # With padding=1, we need to adjust the position to get the correct patch
                    in_h_start = h_idx * stride - padding
                    in_w_start = w_idx * stride - padding
                    in_h_end = in_h_start + kernel_size
                    in_w_end = in_w_start + kernel_size
                    
                    # Extract the input patch accounting for padding
                    input_patch = torch.zeros(input1.shape[1], kernel_size, kernel_size, device=input1.device)
                    
                    for i in range(kernel_size):
                        for j in range(kernel_size):
                            h_pos = in_h_start + i * dilation
                            w_pos = in_w_start + j * dilation
                            
                            # If position is within bounds of input
                            if 0 <= h_pos < input1.shape[2] and 0 <= w_pos < input1.shape[3]:
                                input_patch[:, i, j] = input1[0, :, h_pos, w_pos]

                ####################################

                # compute expected activation with model1 weights so i will be sure that my calculation is correct
                if channel < weights1.shape[0]:
                    kernel1 = weights1[channel]
                    # classic convolution calculation
                    calculated_activation1 = (input_patch * kernel1).sum()
                    
                    if bias1 is not None:
                        calculated_activation1 += bias1[channel]

                    calculated_activation1 = max(0, calculated_activation1.item())  # ReLU
                else:
                    calculated_activation1 = 0
                
                # compute activation using model2 weights with model1 input
                if channel < weights2.shape[0]:
                    kernel2 = weights2[channel]
                    calculated_activation2 = (input_patch * kernel2).sum()
                    if bias2 is not None:
                        calculated_activation2 += bias2[channel]
                    calculated_activation2 = max(0, calculated_activation2.item())  # ReLU
                else:
                    calculated_activation2 = 0
                
                neuron_data = {
                    'type': 'conv',
                    'position': {'channel': int(channel), 'height': int(h_idx), 'width': int(w_idx)},
                    'input_patch': {
                        'data': input_patch.detach().cpu().numpy(),
                        'coords': {'h_start': in_h_start, 'h_end': in_h_end, 
                                  'w_start': in_w_start, 'w_end': in_w_end}
                    }
                }
            else:
                
                flattened_output = stored_output1.view(stored_output1.shape[0], -1)
                
                # check if it is correct when i remove this
                if idx >= flattened_output.shape[1] or idx >= weights1.shape[0]:
                    continue
                
                # get stored activation
                stored_activation = flattened_output[0, idx].item()
                
                # unrolling input for dot product
                flattened_input = input1.flatten(start_dim=1)
                
                 # check if it is correct when i remove this
                if flattened_input.shape[1] != weights1.shape[1]:
                    continue
                
                # calculate model1 activation
                calculated_activation1 = torch.matmul(flattened_input, weights1[idx])
                if bias1 is not None and idx < bias1.shape[0]:
                    calculated_activation1 += bias1[idx]
                calculated_activation1 = max(0, calculated_activation1.item())  # ReLU
                
                # Calculate using model2 weights with model1 input
                calculated_activation2 = torch.matmul(flattened_input, weights2[idx])
                if bias2 is not None and idx < bias2.shape[0]:
                    calculated_activation2 += bias2[idx]
                calculated_activation2 = max(0, calculated_activation2.item())  # ReLU
                
                neuron_data = {
                    'type': 'linear',
                    'position': {'neuron': int(idx)},
                    'input_values': flattened_input.detach().cpu().numpy()
                }
            
            # Calculate verification error (how accurate our calculation is)
            verification_error = abs(stored_activation - calculated_activation1)
            
            # Calculate cross-model difference
            cross_model_difference = abs(calculated_activation1 - calculated_activation2)
            
            # Store comparison for this neuron
            neuron_comparison = {
                'neuron_idx': int(idx),
                'stored_activation': stored_activation,
                'calculated_activation1': calculated_activation1,
                'calculated_activation2': calculated_activation2,
                'verification_error': verification_error,
                'cross_model_difference': cross_model_difference,
                'neuron_data': neuron_data
            }
            
            layer_results['neuron_comparisons'].append(neuron_comparison)
            layer_results['model1_verification_errors'].append(verification_error)
            layer_results['cross_model_differences'].append(cross_model_difference)
        
        # Calculate statistics
        if layer_results['neuron_comparisons']:
            layer_results['mean_verification_error'] = sum(layer_results['model1_verification_errors']) / len(layer_results['model1_verification_errors'])
            layer_results['mean_cross_model_difference'] = sum(layer_results['cross_model_differences']) / len(layer_results['cross_model_differences'])
        else:
            layer_results['mean_verification_error'] = float('nan')
            layer_results['mean_cross_model_difference'] = float('nan')
        
        comparison_results[layer_name] = layer_results
    
    return comparison_results

# %%
classes = {
    0: 'cat',
    1: 'dog'
}

# %%
the_class = 1 # 0 cat or squirrel, 1 dog

# %%
activation_values = {"Model_1":{},
                    "Model_2":{}}

# %%
images = [(img, idx) for idx, (img, label) in enumerate(dataSets["Model_1:Test"].dataset) 
            if label == the_class  and model_1(img.unsqueeze(0).to(DEVICE))
                                          .argmax().item() == the_class]

# %%
layer_stats_columns = [
    'image_id', 'round', 'layer_name', 
    'mean_verification_error', 'mean_cross_model_difference',
]
layer_stats_df = pd.DataFrame(columns=layer_stats_columns)
for image, pic_index in images:
    for i in range(K_ROUND):        
        # register hooks
        hooks1 = register_hooks(model_1, "Model_1")
        hooks2 = register_hooks(model_2, "Model_2")
        
        # clearing
        activation_values["Model_1"] = {}
        activation_values["Model_2"] = {}
        
        # Forward pass
        with torch.no_grad():
            pred1 = model_1(image.unsqueeze(0).to(DEVICE))
            pred2 = model_2(image.unsqueeze(0).to(DEVICE))
        
        # Select random neurons and compare
        selected_indices = select_random_neuron_indices(
            activation_values["Model_1"], 
            n_neurons=1
        )
        result = compare_model_activations(
            activation_values["Model_1"], 
            activation_values["Model_2"], 
            selected_indices
        )
        
        # Process results for each layer
        for layer_name, layer_data in result.items():
            layer_stats_df = pd.concat([layer_stats_df, pd.DataFrame({
                'image_id': [pic_index],
                'round': [i],
                'layer_name': [layer_name],
                'mean_verification_error': [layer_data.get('mean_verification_error', np.nan)],
                'mean_cross_model_difference': [layer_data.get('mean_cross_model_difference', np.nan)]
            })], ignore_index=True)
        
        print('\r ',f"pic_index: {pic_index:02d}", f"round: {i:02d}",end="\n")
        # Remove hooks
        for hook in hooks1 + hooks2:
            hook.remove()
# Out:
# C:\Users\hskay\AppData\Local\Temp\ipykernel_10604\1745977535.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   layer_stats_df = pd.concat([layer_stats_df, pd.DataFrame({
#   pic_index: 100 round: 00
#   pic_index: 100 round: 01
#   pic_index: 100 round: 02
#   pic_index: 100 round: 03
#   pic_index: 100 round: 04
#   pic_index: 100 round: 05
#   pic_index: 100 round: 06
#   pic_index: 100 round: 07
#   pic_index: 100 round: 08
#   pic_index: 100 round: 09
#   pic_index: 100 round: 10
#   pic_index: 100 round: 11
#   pic_index: 100 round: 12
#   pic_index: 100 round: 13
#   pic_index: 100 round: 14
#   pic_index: 100 round: 15
#   pic_index: 100 round: 16
#   pic_index: 100 round: 17
#   pic_index: 100 round: 18
#   pic_index: 100 round: 19
#   pic_index: 100 round: 20
#   pic_index: 100 round: 21
#   pic_index: 100 round: 22
#   pic_index: 100 round: 23
#   pic_index: 100 round: 24
#   pic_index: 100 round: 25
#   pic_index: 100 round: 26
#   pic_index: 100 round: 27
#   pic_index: 100 round: 28
#   pic_index: 100 round: 29
#   pic_index: 100 round: 30
#   pic_index: 100 round: 31
#   pic_index: 100 round: 32
#   pic_index: 100 round: 33
#   pic_index: 100 round: 34
#   pic_index: 100 round: 35
#   pic_index: 100 round: 36
#   pic_index: 100 round: 37
#   pic_index: 100 round: 38
#   pic_index: 100 round: 39
#   pic_index: 100 round: 40
#   pic_index: 100 round: 41
#   pic_index: 100 round: 42
#   pic_index: 100 round: 43
#   pic_index: 100 round: 44
#   pic_index: 100 round: 45
#   pic_index: 100 round: 46
#   pic_index: 100 round: 47
#   pic_index: 100 round: 48
#   pic_index: 100 round: 49
#   pic_index: 101 round: 00
#   pic_index: 101 round: 01
#   pic_index: 101 round: 02
#   pic_index: 101 round: 03
#   pic_index: 101 round: 04
#   pic_index: 101 round: 05
#   pic_index: 101 round: 06
#   pic_index: 101 round: 07
#   pic_index: 101 round: 08
#   pic_index: 101 round: 09
#   pic_index: 101 round: 10
#   pic_index: 101 round: 11
#   pic_index: 101 round: 12
#   pic_index: 101 round: 13
#   pic_index: 101 round: 14
#   pic_index: 101 round: 15
#   pic_index: 101 round: 16
#   pic_index: 101 round: 17
#   pic_index: 101 round: 18
#   pic_index: 101 round: 19
#   pic_index: 101 round: 20
#   pic_index: 101 round: 21
#   pic_index: 101 round: 22
#   pic_index: 101 round: 23
#   pic_index: 101 round: 24
#   pic_index: 101 round: 25
#   pic_index: 101 round: 26
#   pic_index: 101 round: 27
#   pic_index: 101 round: 28
#   pic_index: 101 round: 29
#   pic_index: 101 round: 30
#   pic_index: 101 round: 31
#   pic_index: 101 round: 32
#   pic_index: 101 round: 33
#   pic_index: 101 round: 34
#   pic_index: 101 round: 35
#   pic_index: 101 round: 36
#   pic_index: 101 round: 37
#   pic_index: 101 round: 38
#   pic_index: 101 round: 39
#   pic_index: 101 round: 40
#   pic_index: 101 round: 41
#   pic_index: 101 round: 42
#   pic_index: 101 round: 43
#   pic_index: 101 round: 44
#   pic_index: 101 round: 45
#   pic_index: 101 round: 46
#   pic_index: 101 round: 47
#   pic_index: 101 round: 48
#   pic_index: 101 round: 49
#   pic_index: 102 round: 00
#   pic_index: 102 round: 01
#   pic_index: 102 round: 02
#   pic_index: 102 round: 03
#   pic_index: 102 round: 04
#   pic_index: 102 round: 05
#   pic_index: 102 round: 06
#   pic_index: 102 round: 07
#   pic_index: 102 round: 08
#   pic_index: 102 round: 09
#   pic_index: 102 round: 10
#   pic_index: 102 round: 11
#   pic_index: 102 round: 12
#   pic_index: 102 round: 13
#   pic_index: 102 round: 14
#   pic_index: 102 round: 15
#   pic_index: 102 round: 16
#   pic_index: 102 round: 17
#   pic_index: 102 round: 18
#   pic_index: 102 round: 19
#   pic_index: 102 round: 20
#   pic_index: 102 round: 21
#   pic_index: 102 round: 22
#   pic_index: 102 round: 23
#   pic_index: 102 round: 24
#   pic_index: 102 round: 25
#   pic_index: 102 round: 26
#   pic_index: 102 round: 27
#   pic_index: 102 round: 28
#   pic_index: 102 round: 29
#   pic_index: 102 round: 30
#   pic_index: 102 round: 31
#   pic_index: 102 round: 32
#   pic_index: 102 round: 33
#   pic_index: 102 round: 34
#   pic_index: 102 round: 35
#   pic_index: 102 round: 36
#   pic_index: 102 round: 37
#   pic_index: 102 round: 38
#   pic_index: 102 round: 39
#   pic_index: 102 round: 40
#   pic_index: 102 round: 41
#   pic_index: 102 round: 42
#   pic_index: 102 round: 43
#   pic_index: 102 round: 44
#   pic_index: 102 round: 45
#   pic_index: 102 round: 46
#   pic_index: 102 round: 47
#   pic_index: 102 round: 48
#   pic_index: 102 round: 49
#   pic_index: 103 round: 00
#   pic_index: 103 round: 01
#   pic_index: 103 round: 02
#   pic_index: 103 round: 03
#   pic_index: 103 round: 04
#   pic_index: 103 round: 05
#   pic_index: 103 round: 06
#   pic_index: 103 round: 07
#   pic_index: 103 round: 08
#   pic_index: 103 round: 09
#   pic_index: 103 round: 10
#   pic_index: 103 round: 11
#   pic_index: 103 round: 12
#   pic_index: 103 round: 13
#   pic_index: 103 round: 14
#   pic_index: 103 round: 15
#   pic_index: 103 round: 16
#   pic_index: 103 round: 17
#   pic_index: 103 round: 18
#   pic_index: 103 round: 19
#   pic_index: 103 round: 20
#   pic_index: 103 round: 21
#   pic_index: 103 round: 22
#   pic_index: 103 round: 23
#   pic_index: 103 round: 24
#   pic_index: 103 round: 25
#   pic_index: 103 round: 26
#   pic_index: 103 round: 27
#   pic_index: 103 round: 28
#   pic_index: 103 round: 29
#   pic_index: 103 round: 30
#   pic_index: 103 round: 31
#   pic_index: 103 round: 32
#   pic_index: 103 round: 33
#   pic_index: 103 round: 34
#   pic_index: 103 round: 35
#   pic_index: 103 round: 36
#   pic_index: 103 round: 37
#   pic_index: 103 round: 38
#   pic_index: 103 round: 39
#   pic_index: 103 round: 40
#   pic_index: 103 round: 41
#   pic_index: 103 round: 42
#   pic_index: 103 round: 43
#   pic_index: 103 round: 44
#   pic_index: 103 round: 45
#   pic_index: 103 round: 46
#   pic_index: 103 round: 47
#   pic_index: 103 round: 48
#   pic_index: 103 round: 49
#   pic_index: 104 round: 00
#   pic_index: 104 round: 01
#   pic_index: 104 round: 02
#   pic_index: 104 round: 03
#   pic_index: 104 round: 04
#   pic_index: 104 round: 05
#   pic_index: 104 round: 06
#   pic_index: 104 round: 07
#   pic_index: 104 round: 08
#   pic_index: 104 round: 09
#   pic_index: 104 round: 10
#   pic_index: 104 round: 11
#   pic_index: 104 round: 12
#   pic_index: 104 round: 13
#   pic_index: 104 round: 14
#   pic_index: 104 round: 15
#   pic_index: 104 round: 16
#   pic_index: 104 round: 17
#   pic_index: 104 round: 18
#   pic_index: 104 round: 19
#   pic_index: 104 round: 20
#   pic_index: 104 round: 21
#   pic_index: 104 round: 22
#   pic_index: 104 round: 23
#   pic_index: 104 round: 24
#   pic_index: 104 round: 25
#   pic_index: 104 round: 26
#   pic_index: 104 round: 27
#   pic_index: 104 round: 28
#   pic_index: 104 round: 29
#   pic_index: 104 round: 30
#   pic_index: 104 round: 31
#   pic_index: 104 round: 32
#   pic_index: 104 round: 33
#   pic_index: 104 round: 34
#   pic_index: 104 round: 35
#   pic_index: 104 round: 36
#   pic_index: 104 round: 37
#   pic_index: 104 round: 38
#   pic_index: 104 round: 39
#   pic_index: 104 round: 40
#   pic_index: 104 round: 41
#   pic_index: 104 round: 42
#   pic_index: 104 round: 43
#   pic_index: 104 round: 44
#   pic_index: 104 round: 45
#   pic_index: 104 round: 46
#   pic_index: 104 round: 47
#   pic_index: 104 round: 48
#   pic_index: 104 round: 49
#   pic_index: 105 round: 00
#   pic_index: 105 round: 01
#   pic_index: 105 round: 02
#   pic_index: 105 round: 03
#   pic_index: 105 round: 04
#   pic_index: 105 round: 05
#   pic_index: 105 round: 06
#   pic_index: 105 round: 07
#   pic_index: 105 round: 08
#   pic_index: 105 round: 09
#   pic_index: 105 round: 10
#   pic_index: 105 round: 11
#   pic_index: 105 round: 12
#   pic_index: 105 round: 13
#   pic_index: 105 round: 14
#   pic_index: 105 round: 15
#   pic_index: 105 round: 16
#   pic_index: 105 round: 17
#   pic_index: 105 round: 18
#   pic_index: 105 round: 19
#   pic_index: 105 round: 20
#   pic_index: 105 round: 21
#   pic_index: 105 round: 22
#   pic_index: 105 round: 23
#   pic_index: 105 round: 24
#   pic_index: 105 round: 25
#   pic_index: 105 round: 26
#   pic_index: 105 round: 27
#   pic_index: 105 round: 28
#   pic_index: 105 round: 29
#   pic_index: 105 round: 30
#   pic_index: 105 round: 31
#   pic_index: 105 round: 32
#   pic_index: 105 round: 33
#   pic_index: 105 round: 34
#   pic_index: 105 round: 35
#   pic_index: 105 round: 36
#   pic_index: 105 round: 37
#   pic_index: 105 round: 38
#   pic_index: 105 round: 39
#   pic_index: 105 round: 40
#   pic_index: 105 round: 41
#   pic_index: 105 round: 42
#   pic_index: 105 round: 43
#   pic_index: 105 round: 44
#   pic_index: 105 round: 45
#   pic_index: 105 round: 46
#   pic_index: 105 round: 47
#   pic_index: 105 round: 48
#   pic_index: 105 round: 49
#   pic_index: 106 round: 00
#   pic_index: 106 round: 01
#   pic_index: 106 round: 02
#   pic_index: 106 round: 03
#   pic_index: 106 round: 04
#   pic_index: 106 round: 05
#   pic_index: 106 round: 06
#   pic_index: 106 round: 07
#   pic_index: 106 round: 08
#   pic_index: 106 round: 09
#   pic_index: 106 round: 10
#   pic_index: 106 round: 11
#   pic_index: 106 round: 12
#   pic_index: 106 round: 13
#   pic_index: 106 round: 14
#   pic_index: 106 round: 15
#   pic_index: 106 round: 16
#   pic_index: 106 round: 17
#   pic_index: 106 round: 18
#   pic_index: 106 round: 19
#   pic_index: 106 round: 20
#   pic_index: 106 round: 21
#   pic_index: 106 round: 22
#   pic_index: 106 round: 23
#   pic_index: 106 round: 24
#   pic_index: 106 round: 25
#   pic_index: 106 round: 26
#   pic_index: 106 round: 27
#   pic_index: 106 round: 28
#   pic_index: 106 round: 29
#   pic_index: 106 round: 30
#   pic_index: 106 round: 31
#   pic_index: 106 round: 32
#   pic_index: 106 round: 33
#   pic_index: 106 round: 34
#   pic_index: 106 round: 35
#   pic_index: 106 round: 36
#   pic_index: 106 round: 37
#   pic_index: 106 round: 38
#   pic_index: 106 round: 39
#   pic_index: 106 round: 40
#   pic_index: 106 round: 41
#   pic_index: 106 round: 42
#   pic_index: 106 round: 43
#   pic_index: 106 round: 44
#   pic_index: 106 round: 45
#   pic_index: 106 round: 46
#   pic_index: 106 round: 47
#   pic_index: 106 round: 48
#   pic_index: 106 round: 49
#   pic_index: 107 round: 00
#   pic_index: 107 round: 01
#   pic_index: 107 round: 02
#   pic_index: 107 round: 03
#   pic_index: 107 round: 04
#   pic_index: 107 round: 05
#   pic_index: 107 round: 06
#   pic_index: 107 round: 07
#   pic_index: 107 round: 08
#   pic_index: 107 round: 09
#   pic_index: 107 round: 10
#   pic_index: 107 round: 11
#   pic_index: 107 round: 12
#   pic_index: 107 round: 13
#   pic_index: 107 round: 14
#   pic_index: 107 round: 15
#   pic_index: 107 round: 16
#   pic_index: 107 round: 17
#   pic_index: 107 round: 18
#   pic_index: 107 round: 19
#   pic_index: 107 round: 20
#   pic_index: 107 round: 21
#   pic_index: 107 round: 22
#   pic_index: 107 round: 23
#   pic_index: 107 round: 24
#   pic_index: 107 round: 25
#   pic_index: 107 round: 26
#   pic_index: 107 round: 27
#   pic_index: 107 round: 28
#   pic_index: 107 round: 29
#   pic_index: 107 round: 30
#   pic_index: 107 round: 31
#   pic_index: 107 round: 32
#   pic_index: 107 round: 33
#   pic_index: 107 round: 34
#   pic_index: 107 round: 35
#   pic_index: 107 round: 36
#   pic_index: 107 round: 37
#   pic_index: 107 round: 38
#   pic_index: 107 round: 39
#   pic_index: 107 round: 40
#   pic_index: 107 round: 41
#   pic_index: 107 round: 42
#   pic_index: 107 round: 43
#   pic_index: 107 round: 44
#   pic_index: 107 round: 45
#   pic_index: 107 round: 46
#   pic_index: 107 round: 47
#   pic_index: 107 round: 48
#   pic_index: 107 round: 49
#   pic_index: 108 round: 00
#   pic_index: 108 round: 01
#   pic_index: 108 round: 02
#   pic_index: 108 round: 03
#   pic_index: 108 round: 04
#   pic_index: 108 round: 05
#   pic_index: 108 round: 06
#   pic_index: 108 round: 07
#   pic_index: 108 round: 08
#   pic_index: 108 round: 09
#   pic_index: 108 round: 10
#   pic_index: 108 round: 11
#   pic_index: 108 round: 12
#   pic_index: 108 round: 13
#   pic_index: 108 round: 14
#   pic_index: 108 round: 15
#   pic_index: 108 round: 16
#   pic_index: 108 round: 17
#   pic_index: 108 round: 18
#   pic_index: 108 round: 19
#   pic_index: 108 round: 20
#   pic_index: 108 round: 21
#   pic_index: 108 round: 22
#   pic_index: 108 round: 23
#   pic_index: 108 round: 24
#   pic_index: 108 round: 25
#   pic_index: 108 round: 26
#   pic_index: 108 round: 27
#   pic_index: 108 round: 28
#   pic_index: 108 round: 29
#   pic_index: 108 round: 30
#   pic_index: 108 round: 31
#   pic_index: 108 round: 32
#   pic_index: 108 round: 33
#   pic_index: 108 round: 34
#   pic_index: 108 round: 35
#   pic_index: 108 round: 36
#   pic_index: 108 round: 37
#   pic_index: 108 round: 38
#   pic_index: 108 round: 39
#   pic_index: 108 round: 40
#   pic_index: 108 round: 41
#   pic_index: 108 round: 42
#   pic_index: 108 round: 43
#   pic_index: 108 round: 44
#   pic_index: 108 round: 45
#   pic_index: 108 round: 46
#   pic_index: 108 round: 47
#   pic_index: 108 round: 48
#   pic_index: 108 round: 49
#   pic_index: 109 round: 00
#   pic_index: 109 round: 01
#   pic_index: 109 round: 02
#   pic_index: 109 round: 03
#   pic_index: 109 round: 04
#   pic_index: 109 round: 05
#   pic_index: 109 round: 06
#   pic_index: 109 round: 07
#   pic_index: 109 round: 08
#   pic_index: 109 round: 09
#   pic_index: 109 round: 10
#   pic_index: 109 round: 11
#   pic_index: 109 round: 12
#   pic_index: 109 round: 13
#   pic_index: 109 round: 14
#   pic_index: 109 round: 15
#   pic_index: 109 round: 16
#   pic_index: 109 round: 17
#   pic_index: 109 round: 18
#   pic_index: 109 round: 19
#   pic_index: 109 round: 20
#   pic_index: 109 round: 21
#   pic_index: 109 round: 22
#   pic_index: 109 round: 23
#   pic_index: 109 round: 24
#   pic_index: 109 round: 25
#   pic_index: 109 round: 26
#   pic_index: 109 round: 27
#   pic_index: 109 round: 28
#   pic_index: 109 round: 29
#   pic_index: 109 round: 30
#   pic_index: 109 round: 31
#   pic_index: 109 round: 32
#   pic_index: 109 round: 33
#   pic_index: 109 round: 34
#   pic_index: 109 round: 35
#   pic_index: 109 round: 36
#   pic_index: 109 round: 37
#   pic_index: 109 round: 38
#   pic_index: 109 round: 39
#   pic_index: 109 round: 40
#   pic_index: 109 round: 41
#   pic_index: 109 round: 42
#   pic_index: 109 round: 43
#   pic_index: 109 round: 44
#   pic_index: 109 round: 45
#   pic_index: 109 round: 46
#   pic_index: 109 round: 47
#   pic_index: 109 round: 48
#   pic_index: 109 round: 49
#   pic_index: 110 round: 00
#   pic_index: 110 round: 01
#   pic_index: 110 round: 02
#   pic_index: 110 round: 03
#   pic_index: 110 round: 04
#   pic_index: 110 round: 05
#   pic_index: 110 round: 06
#   pic_index: 110 round: 07
#   pic_index: 110 round: 08
#   pic_index: 110 round: 09
#   pic_index: 110 round: 10
#   pic_index: 110 round: 11
#   pic_index: 110 round: 12
#   pic_index: 110 round: 13
#   pic_index: 110 round: 14
#   pic_index: 110 round: 15
#   pic_index: 110 round: 16
#   pic_index: 110 round: 17
#   pic_index: 110 round: 18
#   pic_index: 110 round: 19
#   pic_index: 110 round: 20
#   pic_index: 110 round: 21
#   pic_index: 110 round: 22
#   pic_index: 110 round: 23
#   pic_index: 110 round: 24
#   pic_index: 110 round: 25
#   pic_index: 110 round: 26
#   pic_index: 110 round: 27
#   pic_index: 110 round: 28
#   pic_index: 110 round: 29
#   pic_index: 110 round: 30
#   pic_index: 110 round: 31
#   pic_index: 110 round: 32
#   pic_index: 110 round: 33
#   pic_index: 110 round: 34
#   pic_index: 110 round: 35
#   pic_index: 110 round: 36
#   pic_index: 110 round: 37
#   pic_index: 110 round: 38
#   pic_index: 110 round: 39
#   pic_index: 110 round: 40
#   pic_index: 110 round: 41
#   pic_index: 110 round: 42
#   pic_index: 110 round: 43
#   pic_index: 110 round: 44
#   pic_index: 110 round: 45
#   pic_index: 110 round: 46
#   pic_index: 110 round: 47
#   pic_index: 110 round: 48
#   pic_index: 110 round: 49
#   pic_index: 112 round: 00
#   pic_index: 112 round: 01
#   pic_index: 112 round: 02
#   pic_index: 112 round: 03
#   pic_index: 112 round: 04
#   pic_index: 112 round: 05
#   pic_index: 112 round: 06
#   pic_index: 112 round: 07
#   pic_index: 112 round: 08
#   pic_index: 112 round: 09
#   pic_index: 112 round: 10
#   pic_index: 112 round: 11
#   pic_index: 112 round: 12
#   pic_index: 112 round: 13
#   pic_index: 112 round: 14
#   pic_index: 112 round: 15
#   pic_index: 112 round: 16
#   pic_index: 112 round: 17
#   pic_index: 112 round: 18
#   pic_index: 112 round: 19
#   pic_index: 112 round: 20
#   pic_index: 112 round: 21
#   pic_index: 112 round: 22
#   pic_index: 112 round: 23
#   pic_index: 112 round: 24
#   pic_index: 112 round: 25
#   pic_index: 112 round: 26
#   pic_index: 112 round: 27
#   pic_index: 112 round: 28
#   pic_index: 112 round: 29
#   pic_index: 112 round: 30
#   pic_index: 112 round: 31
#   pic_index: 112 round: 32
#   pic_index: 112 round: 33
#   pic_index: 112 round: 34
#   pic_index: 112 round: 35
#   pic_index: 112 round: 36
#   pic_index: 112 round: 37
#   pic_index: 112 round: 38
#   pic_index: 112 round: 39
#   pic_index: 112 round: 40
#   pic_index: 112 round: 41
#   pic_index: 112 round: 42
#   pic_index: 112 round: 43
#   pic_index: 112 round: 44
#   pic_index: 112 round: 45
#   pic_index: 112 round: 46
#   pic_index: 112 round: 47
#   pic_index: 112 round: 48
#   pic_index: 112 round: 49
#   pic_index: 113 round: 00
#   pic_index: 113 round: 01
#   pic_index: 113 round: 02
#   pic_index: 113 round: 03
#   pic_index: 113 round: 04
#   pic_index: 113 round: 05
#   pic_index: 113 round: 06
#   pic_index: 113 round: 07
#   pic_index: 113 round: 08
#   pic_index: 113 round: 09
#   pic_index: 113 round: 10
#   pic_index: 113 round: 11
#   pic_index: 113 round: 12
#   pic_index: 113 round: 13
#   pic_index: 113 round: 14
#   pic_index: 113 round: 15
#   pic_index: 113 round: 16
#   pic_index: 113 round: 17
#   pic_index: 113 round: 18
#   pic_index: 113 round: 19
#   pic_index: 113 round: 20
#   pic_index: 113 round: 21
#   pic_index: 113 round: 22
#   pic_index: 113 round: 23
#   pic_index: 113 round: 24
#   pic_index: 113 round: 25
#   pic_index: 113 round: 26
#   pic_index: 113 round: 27
#   pic_index: 113 round: 28
#   pic_index: 113 round: 29
#   pic_index: 113 round: 30
#   pic_index: 113 round: 31
#   pic_index: 113 round: 32
#   pic_index: 113 round: 33
#   pic_index: 113 round: 34
#   pic_index: 113 round: 35
#   pic_index: 113 round: 36
#   pic_index: 113 round: 37
#   pic_index: 113 round: 38
#   pic_index: 113 round: 39
#   pic_index: 113 round: 40
#   pic_index: 113 round: 41
#   pic_index: 113 round: 42
#   pic_index: 113 round: 43
#   pic_index: 113 round: 44
#   pic_index: 113 round: 45
#   pic_index: 113 round: 46
#   pic_index: 113 round: 47
#   pic_index: 113 round: 48
#   pic_index: 113 round: 49
#   pic_index: 114 round: 00
#   pic_index: 114 round: 01
#   pic_index: 114 round: 02
#   pic_index: 114 round: 03
#   pic_index: 114 round: 04
#   pic_index: 114 round: 05
#   pic_index: 114 round: 06
#   pic_index: 114 round: 07
#   pic_index: 114 round: 08
#   pic_index: 114 round: 09
#   pic_index: 114 round: 10
#   pic_index: 114 round: 11
#   pic_index: 114 round: 12
#   pic_index: 114 round: 13
#   pic_index: 114 round: 14
#   pic_index: 114 round: 15
#   pic_index: 114 round: 16
#   pic_index: 114 round: 17
#   pic_index: 114 round: 18
#   pic_index: 114 round: 19
#   pic_index: 114 round: 20
#   pic_index: 114 round: 21
#   pic_index: 114 round: 22
#   pic_index: 114 round: 23
#   pic_index: 114 round: 24
#   pic_index: 114 round: 25
#   pic_index: 114 round: 26
#   pic_index: 114 round: 27
#   pic_index: 114 round: 28
#   pic_index: 114 round: 29
#   pic_index: 114 round: 30
#   pic_index: 114 round: 31
#   pic_index: 114 round: 32
#   pic_index: 114 round: 33
#   pic_index: 114 round: 34
#   pic_index: 114 round: 35
#   pic_index: 114 round: 36
#   pic_index: 114 round: 37
#   pic_index: 114 round: 38
#   pic_index: 114 round: 39
#   pic_index: 114 round: 40
#   pic_index: 114 round: 41
#   pic_index: 114 round: 42
#   pic_index: 114 round: 43
#   pic_index: 114 round: 44
#   pic_index: 114 round: 45
#   pic_index: 114 round: 46
#   pic_index: 114 round: 47
#   pic_index: 114 round: 48
#   pic_index: 114 round: 49
#   pic_index: 115 round: 00
#   pic_index: 115 round: 01
#   pic_index: 115 round: 02
#   pic_index: 115 round: 03
#   pic_index: 115 round: 04
#   pic_index: 115 round: 05
#   pic_index: 115 round: 06
#   pic_index: 115 round: 07
#   pic_index: 115 round: 08
#   pic_index: 115 round: 09
#   pic_index: 115 round: 10
#   pic_index: 115 round: 11
#   pic_index: 115 round: 12
#   pic_index: 115 round: 13
#   pic_index: 115 round: 14
#   pic_index: 115 round: 15
#   pic_index: 115 round: 16
#   pic_index: 115 round: 17
#   pic_index: 115 round: 18
#   pic_index: 115 round: 19
#   pic_index: 115 round: 20
#   pic_index: 115 round: 21
#   pic_index: 115 round: 22
#   pic_index: 115 round: 23
#   pic_index: 115 round: 24
#   pic_index: 115 round: 25
#   pic_index: 115 round: 26
#   pic_index: 115 round: 27
#   pic_index: 115 round: 28
#   pic_index: 115 round: 29
#   pic_index: 115 round: 30
#   pic_index: 115 round: 31
#   pic_index: 115 round: 32
#   pic_index: 115 round: 33
#   pic_index: 115 round: 34
#   pic_index: 115 round: 35
#   pic_index: 115 round: 36
#   pic_index: 115 round: 37
#   pic_index: 115 round: 38
#   pic_index: 115 round: 39
#   pic_index: 115 round: 40
#   pic_index: 115 round: 41
#   pic_index: 115 round: 42
#   pic_index: 115 round: 43
#   pic_index: 115 round: 44
#   pic_index: 115 round: 45
#   pic_index: 115 round: 46
#   pic_index: 115 round: 47
#   pic_index: 115 round: 48
#   pic_index: 115 round: 49
#   pic_index: 116 round: 00
#   pic_index: 116 round: 01
#   pic_index: 116 round: 02
#   pic_index: 116 round: 03
#   pic_index: 116 round: 04
#   pic_index: 116 round: 05
#   pic_index: 116 round: 06
#   pic_index: 116 round: 07
#   pic_index: 116 round: 08
#   pic_index: 116 round: 09
#   pic_index: 116 round: 10
#   pic_index: 116 round: 11
#   pic_index: 116 round: 12
#   pic_index: 116 round: 13
#   pic_index: 116 round: 14
#   pic_index: 116 round: 15
#   pic_index: 116 round: 16
#   pic_index: 116 round: 17
#   pic_index: 116 round: 18
#   pic_index: 116 round: 19
#   pic_index: 116 round: 20
#   pic_index: 116 round: 21
#   pic_index: 116 round: 22
#   pic_index: 116 round: 23
#   pic_index: 116 round: 24
#   pic_index: 116 round: 25
#   pic_index: 116 round: 26
#   pic_index: 116 round: 27
#   pic_index: 116 round: 28
#   pic_index: 116 round: 29
#   pic_index: 116 round: 30
#   pic_index: 116 round: 31
#   pic_index: 116 round: 32
#   pic_index: 116 round: 33
#   pic_index: 116 round: 34
#   pic_index: 116 round: 35
#   pic_index: 116 round: 36
#   pic_index: 116 round: 37
#   pic_index: 116 round: 38
#   pic_index: 116 round: 39
#   pic_index: 116 round: 40
#   pic_index: 116 round: 41
#   pic_index: 116 round: 42
#   pic_index: 116 round: 43
#   pic_index: 116 round: 44
#   pic_index: 116 round: 45
#   pic_index: 116 round: 46
#   pic_index: 116 round: 47
#   pic_index: 116 round: 48
#   pic_index: 116 round: 49
#   pic_index: 117 round: 00
#   pic_index: 117 round: 01
#   pic_index: 117 round: 02
#   pic_index: 117 round: 03
#   pic_index: 117 round: 04
#   pic_index: 117 round: 05
#   pic_index: 117 round: 06
#   pic_index: 117 round: 07
#   pic_index: 117 round: 08
#   pic_index: 117 round: 09
#   pic_index: 117 round: 10
#   pic_index: 117 round: 11
#   pic_index: 117 round: 12
#   pic_index: 117 round: 13
#   pic_index: 117 round: 14
#   pic_index: 117 round: 15
#   pic_index: 117 round: 16
#   pic_index: 117 round: 17
#   pic_index: 117 round: 18
#   pic_index: 117 round: 19
#   pic_index: 117 round: 20
#   pic_index: 117 round: 21
#   pic_index: 117 round: 22
#   pic_index: 117 round: 23
#   pic_index: 117 round: 24
#   pic_index: 117 round: 25
#   pic_index: 117 round: 26
#   pic_index: 117 round: 27
#   pic_index: 117 round: 28
#   pic_index: 117 round: 29
#   pic_index: 117 round: 30
#   pic_index: 117 round: 31
#   pic_index: 117 round: 32
#   pic_index: 117 round: 33
#   pic_index: 117 round: 34
#   pic_index: 117 round: 35
#   pic_index: 117 round: 36
#   pic_index: 117 round: 37
#   pic_index: 117 round: 38
#   pic_index: 117 round: 39
#   pic_index: 117 round: 40
#   pic_index: 117 round: 41
#   pic_index: 117 round: 42
#   pic_index: 117 round: 43
#   pic_index: 117 round: 44
#   pic_index: 117 round: 45
#   pic_index: 117 round: 46
#   pic_index: 117 round: 47
#   pic_index: 117 round: 48
#   pic_index: 117 round: 49
#   pic_index: 118 round: 00
#   pic_index: 118 round: 01
#   pic_index: 118 round: 02
#   pic_index: 118 round: 03
#   pic_index: 118 round: 04
#   pic_index: 118 round: 05
#   pic_index: 118 round: 06
#   pic_index: 118 round: 07
#   pic_index: 118 round: 08
#   pic_index: 118 round: 09
#   pic_index: 118 round: 10
#   pic_index: 118 round: 11
#   pic_index: 118 round: 12
#   pic_index: 118 round: 13
#   pic_index: 118 round: 14
#   pic_index: 118 round: 15
#   pic_index: 118 round: 16
#   pic_index: 118 round: 17
#   pic_index: 118 round: 18
#   pic_index: 118 round: 19
#   pic_index: 118 round: 20
#   pic_index: 118 round: 21
#   pic_index: 118 round: 22
#   pic_index: 118 round: 23
#   pic_index: 118 round: 24
#   pic_index: 118 round: 25
#   pic_index: 118 round: 26
#   pic_index: 118 round: 27
#   pic_index: 118 round: 28
#   pic_index: 118 round: 29
#   pic_index: 118 round: 30
#   pic_index: 118 round: 31
#   pic_index: 118 round: 32
#   pic_index: 118 round: 33
#   pic_index: 118 round: 34
#   pic_index: 118 round: 35
#   pic_index: 118 round: 36
#   pic_index: 118 round: 37
#   pic_index: 118 round: 38
#   pic_index: 118 round: 39
#   pic_index: 118 round: 40
#   pic_index: 118 round: 41
#   pic_index: 118 round: 42
#   pic_index: 118 round: 43
#   pic_index: 118 round: 44
#   pic_index: 118 round: 45
#   pic_index: 118 round: 46
#   pic_index: 118 round: 47
#   pic_index: 118 round: 48
#   pic_index: 118 round: 49
#   pic_index: 119 round: 00
#   pic_index: 119 round: 01
#   pic_index: 119 round: 02
#   pic_index: 119 round: 03
#   pic_index: 119 round: 04
#   pic_index: 119 round: 05
#   pic_index: 119 round: 06
#   pic_index: 119 round: 07
#   pic_index: 119 round: 08
#   pic_index: 119 round: 09
#   pic_index: 119 round: 10
#   pic_index: 119 round: 11
#   pic_index: 119 round: 12
#   pic_index: 119 round: 13
#   pic_index: 119 round: 14
#   pic_index: 119 round: 15
#   pic_index: 119 round: 16
#   pic_index: 119 round: 17
#   pic_index: 119 round: 18
#   pic_index: 119 round: 19
#   pic_index: 119 round: 20
#   pic_index: 119 round: 21
#   pic_index: 119 round: 22
#   pic_index: 119 round: 23
#   pic_index: 119 round: 24
#   pic_index: 119 round: 25
#   pic_index: 119 round: 26
#   pic_index: 119 round: 27
#   pic_index: 119 round: 28
#   pic_index: 119 round: 29
#   pic_index: 119 round: 30
#   pic_index: 119 round: 31
#   pic_index: 119 round: 32
#   pic_index: 119 round: 33
#   pic_index: 119 round: 34
#   pic_index: 119 round: 35
#   pic_index: 119 round: 36
#   pic_index: 119 round: 37
#   pic_index: 119 round: 38
#   pic_index: 119 round: 39
#   pic_index: 119 round: 40
#   pic_index: 119 round: 41
#   pic_index: 119 round: 42
#   pic_index: 119 round: 43
#   pic_index: 119 round: 44
#   pic_index: 119 round: 45
#   pic_index: 119 round: 46
#   pic_index: 119 round: 47
#   pic_index: 119 round: 48
#   pic_index: 119 round: 49
#   pic_index: 120 round: 00
#   pic_index: 120 round: 01
#   pic_index: 120 round: 02
#   pic_index: 120 round: 03
#   pic_index: 120 round: 04
#   pic_index: 120 round: 05
#   pic_index: 120 round: 06
#   pic_index: 120 round: 07
#   pic_index: 120 round: 08
#   pic_index: 120 round: 09
#   pic_index: 120 round: 10
#   pic_index: 120 round: 11
#   pic_index: 120 round: 12
#   pic_index: 120 round: 13
#   pic_index: 120 round: 14
#   pic_index: 120 round: 15
#   pic_index: 120 round: 16
#   pic_index: 120 round: 17
#   pic_index: 120 round: 18
#   pic_index: 120 round: 19
#   pic_index: 120 round: 20
#   pic_index: 120 round: 21
#   pic_index: 120 round: 22
#   pic_index: 120 round: 23
#   pic_index: 120 round: 24
#   pic_index: 120 round: 25
#   pic_index: 120 round: 26
#   pic_index: 120 round: 27
#   pic_index: 120 round: 28
#   pic_index: 120 round: 29
#   pic_index: 120 round: 30
#   pic_index: 120 round: 31
#   pic_index: 120 round: 32
#   pic_index: 120 round: 33
#   pic_index: 120 round: 34
#   pic_index: 120 round: 35
#   pic_index: 120 round: 36
#   pic_index: 120 round: 37
#   pic_index: 120 round: 38
#   pic_index: 120 round: 39
#   pic_index: 120 round: 40
#   pic_index: 120 round: 41
#   pic_index: 120 round: 42
#   pic_index: 120 round: 43
#   pic_index: 120 round: 44
#   pic_index: 120 round: 45
#   pic_index: 120 round: 46
#   pic_index: 120 round: 47
#   pic_index: 120 round: 48
#   pic_index: 120 round: 49
#   pic_index: 121 round: 00
#   pic_index: 121 round: 01
#   pic_index: 121 round: 02
#   pic_index: 121 round: 03
#   pic_index: 121 round: 04
#   pic_index: 121 round: 05
#   pic_index: 121 round: 06
#   pic_index: 121 round: 07
#   pic_index: 121 round: 08
#   pic_index: 121 round: 09
#   pic_index: 121 round: 10
#   pic_index: 121 round: 11
#   pic_index: 121 round: 12
#   pic_index: 121 round: 13
#   pic_index: 121 round: 14
#   pic_index: 121 round: 15
#   pic_index: 121 round: 16
#   pic_index: 121 round: 17
#   pic_index: 121 round: 18
#   pic_index: 121 round: 19
#   pic_index: 121 round: 20
#   pic_index: 121 round: 21
#   pic_index: 121 round: 22
#   pic_index: 121 round: 23
#   pic_index: 121 round: 24
#   pic_index: 121 round: 25
#   pic_index: 121 round: 26
#   pic_index: 121 round: 27
#   pic_index: 121 round: 28
#   pic_index: 121 round: 29
#   pic_index: 121 round: 30
#   pic_index: 121 round: 31
#   pic_index: 121 round: 32
#   pic_index: 121 round: 33
#   pic_index: 121 round: 34
#   pic_index: 121 round: 35
#   pic_index: 121 round: 36
#   pic_index: 121 round: 37
#   pic_index: 121 round: 38
#   pic_index: 121 round: 39
#   pic_index: 121 round: 40
#   pic_index: 121 round: 41
#   pic_index: 121 round: 42
#   pic_index: 121 round: 43
#   pic_index: 121 round: 44
#   pic_index: 121 round: 45
#   pic_index: 121 round: 46
#   pic_index: 121 round: 47
#   pic_index: 121 round: 48
#   pic_index: 121 round: 49
#   pic_index: 122 round: 00
#   pic_index: 122 round: 01
#   pic_index: 122 round: 02
#   pic_index: 122 round: 03
#   pic_index: 122 round: 04
#   pic_index: 122 round: 05
#   pic_index: 122 round: 06
#   pic_index: 122 round: 07
#   pic_index: 122 round: 08
#   pic_index: 122 round: 09
#   pic_index: 122 round: 10
#   pic_index: 122 round: 11
#   pic_index: 122 round: 12
#   pic_index: 122 round: 13
#   pic_index: 122 round: 14
#   pic_index: 122 round: 15
#   pic_index: 122 round: 16
#   pic_index: 122 round: 17
#   pic_index: 122 round: 18
#   pic_index: 122 round: 19
#   pic_index: 122 round: 20
#   pic_index: 122 round: 21
#   pic_index: 122 round: 22
#   pic_index: 122 round: 23
#   pic_index: 122 round: 24
#   pic_index: 122 round: 25
#   pic_index: 122 round: 26
#   pic_index: 122 round: 27
#   pic_index: 122 round: 28
#   pic_index: 122 round: 29
#   pic_index: 122 round: 30
#   pic_index: 122 round: 31
#   pic_index: 122 round: 32
#   pic_index: 122 round: 33
#   pic_index: 122 round: 34
#   pic_index: 122 round: 35
#   pic_index: 122 round: 36
#   pic_index: 122 round: 37
#   pic_index: 122 round: 38
#   pic_index: 122 round: 39
#   pic_index: 122 round: 40
#   pic_index: 122 round: 41
#   pic_index: 122 round: 42
#   pic_index: 122 round: 43
#   pic_index: 122 round: 44
#   pic_index: 122 round: 45
#   pic_index: 122 round: 46
#   pic_index: 122 round: 47
#   pic_index: 122 round: 48
#   pic_index: 122 round: 49
#   pic_index: 123 round: 00
#   pic_index: 123 round: 01
#   pic_index: 123 round: 02
#   pic_index: 123 round: 03
#   pic_index: 123 round: 04
#   pic_index: 123 round: 05
#   pic_index: 123 round: 06
#   pic_index: 123 round: 07
#   pic_index: 123 round: 08
#   pic_index: 123 round: 09
#   pic_index: 123 round: 10
#   pic_index: 123 round: 11
#   pic_index: 123 round: 12
#   pic_index: 123 round: 13
#   pic_index: 123 round: 14
#   pic_index: 123 round: 15
#   pic_index: 123 round: 16
#   pic_index: 123 round: 17
#   pic_index: 123 round: 18
#   pic_index: 123 round: 19
#   pic_index: 123 round: 20
#   pic_index: 123 round: 21
#   pic_index: 123 round: 22
#   pic_index: 123 round: 23
#   pic_index: 123 round: 24
#   pic_index: 123 round: 25
#   pic_index: 123 round: 26
#   pic_index: 123 round: 27
#   pic_index: 123 round: 28
#   pic_index: 123 round: 29
#   pic_index: 123 round: 30
#   pic_index: 123 round: 31
#   pic_index: 123 round: 32
#   pic_index: 123 round: 33
#   pic_index: 123 round: 34
#   pic_index: 123 round: 35
#   pic_index: 123 round: 36
#   pic_index: 123 round: 37
#   pic_index: 123 round: 38
#   pic_index: 123 round: 39
#   pic_index: 123 round: 40
#   pic_index: 123 round: 41
#   pic_index: 123 round: 42
#   pic_index: 123 round: 43
#   pic_index: 123 round: 44
#   pic_index: 123 round: 45
#   pic_index: 123 round: 46
#   pic_index: 123 round: 47
#   pic_index: 123 round: 48
#   pic_index: 123 round: 49
#   pic_index: 124 round: 00
#   pic_index: 124 round: 01
#   pic_index: 124 round: 02
#   pic_index: 124 round: 03
#   pic_index: 124 round: 04
#   pic_index: 124 round: 05
#   pic_index: 124 round: 06
#   pic_index: 124 round: 07
#   pic_index: 124 round: 08
#   pic_index: 124 round: 09
#   pic_index: 124 round: 10
#   pic_index: 124 round: 11
#   pic_index: 124 round: 12
#   pic_index: 124 round: 13
#   pic_index: 124 round: 14
#   pic_index: 124 round: 15
#   pic_index: 124 round: 16
#   pic_index: 124 round: 17
#   pic_index: 124 round: 18
#   pic_index: 124 round: 19
#   pic_index: 124 round: 20
#   pic_index: 124 round: 21
#   pic_index: 124 round: 22
#   pic_index: 124 round: 23
#   pic_index: 124 round: 24
#   pic_index: 124 round: 25
#   pic_index: 124 round: 26
#   pic_index: 124 round: 27
#   pic_index: 124 round: 28
#   pic_index: 124 round: 29
#   pic_index: 124 round: 30
#   pic_index: 124 round: 31
#   pic_index: 124 round: 32
#   pic_index: 124 round: 33
#   pic_index: 124 round: 34
#   pic_index: 124 round: 35
#   pic_index: 124 round: 36
#   pic_index: 124 round: 37
#   pic_index: 124 round: 38
#   pic_index: 124 round: 39
#   pic_index: 124 round: 40
#   pic_index: 124 round: 41
#   pic_index: 124 round: 42
#   pic_index: 124 round: 43
#   pic_index: 124 round: 44
#   pic_index: 124 round: 45
#   pic_index: 124 round: 46
#   pic_index: 124 round: 47
#   pic_index: 124 round: 48
#   pic_index: 124 round: 49
#   pic_index: 125 round: 00
#   pic_index: 125 round: 01
#   pic_index: 125 round: 02
#   pic_index: 125 round: 03
#   pic_index: 125 round: 04
#   pic_index: 125 round: 05
#   pic_index: 125 round: 06
#   pic_index: 125 round: 07
#   pic_index: 125 round: 08
#   pic_index: 125 round: 09
#   pic_index: 125 round: 10
#   pic_index: 125 round: 11
#   pic_index: 125 round: 12
#   pic_index: 125 round: 13
#   pic_index: 125 round: 14
#   pic_index: 125 round: 15
#   pic_index: 125 round: 16
#   pic_index: 125 round: 17
#   pic_index: 125 round: 18
#   pic_index: 125 round: 19
#   pic_index: 125 round: 20
#   pic_index: 125 round: 21
#   pic_index: 125 round: 22
#   pic_index: 125 round: 23
#   pic_index: 125 round: 24
#   pic_index: 125 round: 25
#   pic_index: 125 round: 26
#   pic_index: 125 round: 27
#   pic_index: 125 round: 28
#   pic_index: 125 round: 29
#   pic_index: 125 round: 30
#   pic_index: 125 round: 31
#   pic_index: 125 round: 32
#   pic_index: 125 round: 33
#   pic_index: 125 round: 34
#   pic_index: 125 round: 35
#   pic_index: 125 round: 36
#   pic_index: 125 round: 37
#   pic_index: 125 round: 38
#   pic_index: 125 round: 39
#   pic_index: 125 round: 40
#   pic_index: 125 round: 41
#   pic_index: 125 round: 42
#   pic_index: 125 round: 43
#   pic_index: 125 round: 44
#   pic_index: 125 round: 45
#   pic_index: 125 round: 46
#   pic_index: 125 round: 47
#   pic_index: 125 round: 48
#   pic_index: 125 round: 49
#   pic_index: 126 round: 00
#   pic_index: 126 round: 01
#   pic_index: 126 round: 02
#   pic_index: 126 round: 03
#   pic_index: 126 round: 04
#   pic_index: 126 round: 05
#   pic_index: 126 round: 06
#   pic_index: 126 round: 07
#   pic_index: 126 round: 08
#   pic_index: 126 round: 09
#   pic_index: 126 round: 10
#   pic_index: 126 round: 11
#   pic_index: 126 round: 12
#   pic_index: 126 round: 13
#   pic_index: 126 round: 14
#   pic_index: 126 round: 15
#   pic_index: 126 round: 16
#   pic_index: 126 round: 17
#   pic_index: 126 round: 18
#   pic_index: 126 round: 19
#   pic_index: 126 round: 20
#   pic_index: 126 round: 21
#   pic_index: 126 round: 22
#   pic_index: 126 round: 23
#   pic_index: 126 round: 24
#   pic_index: 126 round: 25
#   pic_index: 126 round: 26
#   pic_index: 126 round: 27
#   pic_index: 126 round: 28
#   pic_index: 126 round: 29
#   pic_index: 126 round: 30
#   pic_index: 126 round: 31
#   pic_index: 126 round: 32
#   pic_index: 126 round: 33
#   pic_index: 126 round: 34
#   pic_index: 126 round: 35
#   pic_index: 126 round: 36
#   pic_index: 126 round: 37
#   pic_index: 126 round: 38
#   pic_index: 126 round: 39
#   pic_index: 126 round: 40
#   pic_index: 126 round: 41
#   pic_index: 126 round: 42
#   pic_index: 126 round: 43
#   pic_index: 126 round: 44
#   pic_index: 126 round: 45
#   pic_index: 126 round: 46
#   pic_index: 126 round: 47
#   pic_index: 126 round: 48
#   pic_index: 126 round: 49
#   pic_index: 127 round: 00
#   pic_index: 127 round: 01
#   pic_index: 127 round: 02
#   pic_index: 127 round: 03
#   pic_index: 127 round: 04
#   pic_index: 127 round: 05
#   pic_index: 127 round: 06
#   pic_index: 127 round: 07
#   pic_index: 127 round: 08
#   pic_index: 127 round: 09
#   pic_index: 127 round: 10
#   pic_index: 127 round: 11
#   pic_index: 127 round: 12
#   pic_index: 127 round: 13
#   pic_index: 127 round: 14
#   pic_index: 127 round: 15
#   pic_index: 127 round: 16
#   pic_index: 127 round: 17
#   pic_index: 127 round: 18
#   pic_index: 127 round: 19
#   pic_index: 127 round: 20
#   pic_index: 127 round: 21
#   pic_index: 127 round: 22
#   pic_index: 127 round: 23
#   pic_index: 127 round: 24
#   pic_index: 127 round: 25
#   pic_index: 127 round: 26
#   pic_index: 127 round: 27
#   pic_index: 127 round: 28
#   pic_index: 127 round: 29
#   pic_index: 127 round: 30
#   pic_index: 127 round: 31
#   pic_index: 127 round: 32
#   pic_index: 127 round: 33
#   pic_index: 127 round: 34
#   pic_index: 127 round: 35
#   pic_index: 127 round: 36
#   pic_index: 127 round: 37
#   pic_index: 127 round: 38
#   pic_index: 127 round: 39
#   pic_index: 127 round: 40
#   pic_index: 127 round: 41
#   pic_index: 127 round: 42
#   pic_index: 127 round: 43
#   pic_index: 127 round: 44
#   pic_index: 127 round: 45
#   pic_index: 127 round: 46
#   pic_index: 127 round: 47
#   pic_index: 127 round: 48
#   pic_index: 127 round: 49
#   pic_index: 128 round: 00
#   pic_index: 128 round: 01
#   pic_index: 128 round: 02
#   pic_index: 128 round: 03
#   pic_index: 128 round: 04
#   pic_index: 128 round: 05
#   pic_index: 128 round: 06
#   pic_index: 128 round: 07
#   pic_index: 128 round: 08
#   pic_index: 128 round: 09
#   pic_index: 128 round: 10
#   pic_index: 128 round: 11
#   pic_index: 128 round: 12
#   pic_index: 128 round: 13
#   pic_index: 128 round: 14
#   pic_index: 128 round: 15
#   pic_index: 128 round: 16
#   pic_index: 128 round: 17
#   pic_index: 128 round: 18
#   pic_index: 128 round: 19
#   pic_index: 128 round: 20
#   pic_index: 128 round: 21
#   pic_index: 128 round: 22
#   pic_index: 128 round: 23
#   pic_index: 128 round: 24
#   pic_index: 128 round: 25
#   pic_index: 128 round: 26
#   pic_index: 128 round: 27
#   pic_index: 128 round: 28
#   pic_index: 128 round: 29
#   pic_index: 128 round: 30
#   pic_index: 128 round: 31
#   pic_index: 128 round: 32
#   pic_index: 128 round: 33
#   pic_index: 128 round: 34
#   pic_index: 128 round: 35
#   pic_index: 128 round: 36
#   pic_index: 128 round: 37
#   pic_index: 128 round: 38
#   pic_index: 128 round: 39
#   pic_index: 128 round: 40
#   pic_index: 128 round: 41
#   pic_index: 128 round: 42
#   pic_index: 128 round: 43
#   pic_index: 128 round: 44
#   pic_index: 128 round: 45
#   pic_index: 128 round: 46
#   pic_index: 128 round: 47
#   pic_index: 128 round: 48
#   pic_index: 128 round: 49
#   pic_index: 129 round: 00
#   pic_index: 129 round: 01
#   pic_index: 129 round: 02
#   pic_index: 129 round: 03
#   pic_index: 129 round: 04
#   pic_index: 129 round: 05
#   pic_index: 129 round: 06
#   pic_index: 129 round: 07
#   pic_index: 129 round: 08
#   pic_index: 129 round: 09
#   pic_index: 129 round: 10
#   pic_index: 129 round: 11
#   pic_index: 129 round: 12
#   pic_index: 129 round: 13
#   pic_index: 129 round: 14
#   pic_index: 129 round: 15
#   pic_index: 129 round: 16
#   pic_index: 129 round: 17
#   pic_index: 129 round: 18
#   pic_index: 129 round: 19
#   pic_index: 129 round: 20
#   pic_index: 129 round: 21
#   pic_index: 129 round: 22
#   pic_index: 129 round: 23
#   pic_index: 129 round: 24
#   pic_index: 129 round: 25
#   pic_index: 129 round: 26
#   pic_index: 129 round: 27
#   pic_index: 129 round: 28
#   pic_index: 129 round: 29
#   pic_index: 129 round: 30
#   pic_index: 129 round: 31
#   pic_index: 129 round: 32
#   pic_index: 129 round: 33
#   pic_index: 129 round: 34
#   pic_index: 129 round: 35
#   pic_index: 129 round: 36
#   pic_index: 129 round: 37
#   pic_index: 129 round: 38
#   pic_index: 129 round: 39
#   pic_index: 129 round: 40
#   pic_index: 129 round: 41
#   pic_index: 129 round: 42
#   pic_index: 129 round: 43
#   pic_index: 129 round: 44
#   pic_index: 129 round: 45
#   pic_index: 129 round: 46
#   pic_index: 129 round: 47
#   pic_index: 129 round: 48
#   pic_index: 129 round: 49
#   pic_index: 130 round: 00
#   pic_index: 130 round: 01
#   pic_index: 130 round: 02
#   pic_index: 130 round: 03
#   pic_index: 130 round: 04
#   pic_index: 130 round: 05
#   pic_index: 130 round: 06
#   pic_index: 130 round: 07
#   pic_index: 130 round: 08
#   pic_index: 130 round: 09
#   pic_index: 130 round: 10
#   pic_index: 130 round: 11
#   pic_index: 130 round: 12
#   pic_index: 130 round: 13
#   pic_index: 130 round: 14
#   pic_index: 130 round: 15
#   pic_index: 130 round: 16
#   pic_index: 130 round: 17
#   pic_index: 130 round: 18
#   pic_index: 130 round: 19
#   pic_index: 130 round: 20
#   pic_index: 130 round: 21
#   pic_index: 130 round: 22
#   pic_index: 130 round: 23
#   pic_index: 130 round: 24
#   pic_index: 130 round: 25
#   pic_index: 130 round: 26
#   pic_index: 130 round: 27
#   pic_index: 130 round: 28
#   pic_index: 130 round: 29
#   pic_index: 130 round: 30
#   pic_index: 130 round: 31
#   pic_index: 130 round: 32
#   pic_index: 130 round: 33
#   pic_index: 130 round: 34
#   pic_index: 130 round: 35
#   pic_index: 130 round: 36
#   pic_index: 130 round: 37
#   pic_index: 130 round: 38
#   pic_index: 130 round: 39
#   pic_index: 130 round: 40
#   pic_index: 130 round: 41
#   pic_index: 130 round: 42
#   pic_index: 130 round: 43
#   pic_index: 130 round: 44
#   pic_index: 130 round: 45
#   pic_index: 130 round: 46
#   pic_index: 130 round: 47
#   pic_index: 130 round: 48
#   pic_index: 130 round: 49
#   pic_index: 131 round: 00
#   pic_index: 131 round: 01
#   pic_index: 131 round: 02
#   pic_index: 131 round: 03
#   pic_index: 131 round: 04
#   pic_index: 131 round: 05
#   pic_index: 131 round: 06
#   pic_index: 131 round: 07
#   pic_index: 131 round: 08
#   pic_index: 131 round: 09
#   pic_index: 131 round: 10
#   pic_index: 131 round: 11
#   pic_index: 131 round: 12
#   pic_index: 131 round: 13
#   pic_index: 131 round: 14
#   pic_index: 131 round: 15
#   pic_index: 131 round: 16
#   pic_index: 131 round: 17
#   pic_index: 131 round: 18
#   pic_index: 131 round: 19
#   pic_index: 131 round: 20
#   pic_index: 131 round: 21
#   pic_index: 131 round: 22
#   pic_index: 131 round: 23
#   pic_index: 131 round: 24
#   pic_index: 131 round: 25
#   pic_index: 131 round: 26
#   pic_index: 131 round: 27
#   pic_index: 131 round: 28
#   pic_index: 131 round: 29
#   pic_index: 131 round: 30
#   pic_index: 131 round: 31
#   pic_index: 131 round: 32
#   pic_index: 131 round: 33
#   pic_index: 131 round: 34
#   pic_index: 131 round: 35
#   pic_index: 131 round: 36
#   pic_index: 131 round: 37
#   pic_index: 131 round: 38
#   pic_index: 131 round: 39
#   pic_index: 131 round: 40
#   pic_index: 131 round: 41
#   pic_index: 131 round: 42
#   pic_index: 131 round: 43
#   pic_index: 131 round: 44
#   pic_index: 131 round: 45
#   pic_index: 131 round: 46
#   pic_index: 131 round: 47
#   pic_index: 131 round: 48
#   pic_index: 131 round: 49
#   pic_index: 132 round: 00
#   pic_index: 132 round: 01
#   pic_index: 132 round: 02
#   pic_index: 132 round: 03
#   pic_index: 132 round: 04
#   pic_index: 132 round: 05
#   pic_index: 132 round: 06
#   pic_index: 132 round: 07
#   pic_index: 132 round: 08
#   pic_index: 132 round: 09
#   pic_index: 132 round: 10
#   pic_index: 132 round: 11
#   pic_index: 132 round: 12
#   pic_index: 132 round: 13
#   pic_index: 132 round: 14
#   pic_index: 132 round: 15
#   pic_index: 132 round: 16
#   pic_index: 132 round: 17
#   pic_index: 132 round: 18
#   pic_index: 132 round: 19
#   pic_index: 132 round: 20
#   pic_index: 132 round: 21
#   pic_index: 132 round: 22
#   pic_index: 132 round: 23
#   pic_index: 132 round: 24
#   pic_index: 132 round: 25
#   pic_index: 132 round: 26
#   pic_index: 132 round: 27
#   pic_index: 132 round: 28
#   pic_index: 132 round: 29
#   pic_index: 132 round: 30
#   pic_index: 132 round: 31
#   pic_index: 132 round: 32
#   pic_index: 132 round: 33
#   pic_index: 132 round: 34
#   pic_index: 132 round: 35
#   pic_index: 132 round: 36
#   pic_index: 132 round: 37
#   pic_index: 132 round: 38
#   pic_index: 132 round: 39
#   pic_index: 132 round: 40
#   pic_index: 132 round: 41
#   pic_index: 132 round: 42
#   pic_index: 132 round: 43
#   pic_index: 132 round: 44
#   pic_index: 132 round: 45
#   pic_index: 132 round: 46
#   pic_index: 132 round: 47
#   pic_index: 132 round: 48
#   pic_index: 132 round: 49
#   pic_index: 133 round: 00
#   pic_index: 133 round: 01
#   pic_index: 133 round: 02
#   pic_index: 133 round: 03
#   pic_index: 133 round: 04
#   pic_index: 133 round: 05
#   pic_index: 133 round: 06
#   pic_index: 133 round: 07
#   pic_index: 133 round: 08
#   pic_index: 133 round: 09
#   pic_index: 133 round: 10
#   pic_index: 133 round: 11
#   pic_index: 133 round: 12
#   pic_index: 133 round: 13
#   pic_index: 133 round: 14
#   pic_index: 133 round: 15
#   pic_index: 133 round: 16
#   pic_index: 133 round: 17
#   pic_index: 133 round: 18
#   pic_index: 133 round: 19
#   pic_index: 133 round: 20
#   pic_index: 133 round: 21
#   pic_index: 133 round: 22
#   pic_index: 133 round: 23
#   pic_index: 133 round: 24
#   pic_index: 133 round: 25
#   pic_index: 133 round: 26
#   pic_index: 133 round: 27
#   pic_index: 133 round: 28
#   pic_index: 133 round: 29
#   pic_index: 133 round: 30
#   pic_index: 133 round: 31
#   pic_index: 133 round: 32
#   pic_index: 133 round: 33
#   pic_index: 133 round: 34
#   pic_index: 133 round: 35
#   pic_index: 133 round: 36
#   pic_index: 133 round: 37
#   pic_index: 133 round: 38
#   pic_index: 133 round: 39
#   pic_index: 133 round: 40
#   pic_index: 133 round: 41
#   pic_index: 133 round: 42
#   pic_index: 133 round: 43
#   pic_index: 133 round: 44
#   pic_index: 133 round: 45
#   pic_index: 133 round: 46
#   pic_index: 133 round: 47
#   pic_index: 133 round: 48
#   pic_index: 133 round: 49
#   pic_index: 134 round: 00
#   pic_index: 134 round: 01
#   pic_index: 134 round: 02
#   pic_index: 134 round: 03
#   pic_index: 134 round: 04
#   pic_index: 134 round: 05
#   pic_index: 134 round: 06
#   pic_index: 134 round: 07
#   pic_index: 134 round: 08
#   pic_index: 134 round: 09
#   pic_index: 134 round: 10
#   pic_index: 134 round: 11
#   pic_index: 134 round: 12
#   pic_index: 134 round: 13
#   pic_index: 134 round: 14
#   pic_index: 134 round: 15
#   pic_index: 134 round: 16
#   pic_index: 134 round: 17
#   pic_index: 134 round: 18
#   pic_index: 134 round: 19
#   pic_index: 134 round: 20
#   pic_index: 134 round: 21
#   pic_index: 134 round: 22
#   pic_index: 134 round: 23
#   pic_index: 134 round: 24
#   pic_index: 134 round: 25
#   pic_index: 134 round: 26
#   pic_index: 134 round: 27
#   pic_index: 134 round: 28
#   pic_index: 134 round: 29
#   pic_index: 134 round: 30
#   pic_index: 134 round: 31
#   pic_index: 134 round: 32
#   pic_index: 134 round: 33
#   pic_index: 134 round: 34
#   pic_index: 134 round: 35
#   pic_index: 134 round: 36
#   pic_index: 134 round: 37
#   pic_index: 134 round: 38
#   pic_index: 134 round: 39
#   pic_index: 134 round: 40
#   pic_index: 134 round: 41
#   pic_index: 134 round: 42
#   pic_index: 134 round: 43
#   pic_index: 134 round: 44
#   pic_index: 134 round: 45
#   pic_index: 134 round: 46
#   pic_index: 134 round: 47
#   pic_index: 134 round: 48
#   pic_index: 134 round: 49
#   pic_index: 135 round: 00
#   pic_index: 135 round: 01
#   pic_index: 135 round: 02
#   pic_index: 135 round: 03
#   pic_index: 135 round: 04
#   pic_index: 135 round: 05
#   pic_index: 135 round: 06
#   pic_index: 135 round: 07
#   pic_index: 135 round: 08
#   pic_index: 135 round: 09
#   pic_index: 135 round: 10
#   pic_index: 135 round: 11
#   pic_index: 135 round: 12
#   pic_index: 135 round: 13
#   pic_index: 135 round: 14
#   pic_index: 135 round: 15
#   pic_index: 135 round: 16
#   pic_index: 135 round: 17
#   pic_index: 135 round: 18
#   pic_index: 135 round: 19
#   pic_index: 135 round: 20
#   pic_index: 135 round: 21
#   pic_index: 135 round: 22
#   pic_index: 135 round: 23
#   pic_index: 135 round: 24
#   pic_index: 135 round: 25
#   pic_index: 135 round: 26
#   pic_index: 135 round: 27
#   pic_index: 135 round: 28
#   pic_index: 135 round: 29
#   pic_index: 135 round: 30
#   pic_index: 135 round: 31
#   pic_index: 135 round: 32
#   pic_index: 135 round: 33
#   pic_index: 135 round: 34
#   pic_index: 135 round: 35
#   pic_index: 135 round: 36
#   pic_index: 135 round: 37
#   pic_index: 135 round: 38
#   pic_index: 135 round: 39
#   pic_index: 135 round: 40
#   pic_index: 135 round: 41
#   pic_index: 135 round: 42
#   pic_index: 135 round: 43
#   pic_index: 135 round: 44
#   pic_index: 135 round: 45
#   pic_index: 135 round: 46
#   pic_index: 135 round: 47
#   pic_index: 135 round: 48
#   pic_index: 135 round: 49
#   pic_index: 136 round: 00
#   pic_index: 136 round: 01
#   pic_index: 136 round: 02
#   pic_index: 136 round: 03
#   pic_index: 136 round: 04
#   pic_index: 136 round: 05
#   pic_index: 136 round: 06
#   pic_index: 136 round: 07
#   pic_index: 136 round: 08
#   pic_index: 136 round: 09
#   pic_index: 136 round: 10
#   pic_index: 136 round: 11
# ...
#   pic_index: 187 round: 08
#   pic_index: 187 round: 09
#   pic_index: 187 round: 10
#   pic_index: 187 round: 11
#   pic_index: 187 round: 12
#   pic_index: 187 round: 13
#   pic_index: 187 round: 14
#   pic_index: 187 round: 15
#   pic_index: 187 round: 16
#   pic_index: 187 round: 17
#   pic_index: 187 round: 18
#   pic_index: 187 round: 19
#   pic_index: 187 round: 20
#   pic_index: 187 round: 21
#   pic_index: 187 round: 22
#   pic_index: 187 round: 23
#   pic_index: 187 round: 24
#   pic_index: 187 round: 25
#   pic_index: 187 round: 26
#   pic_index: 187 round: 27
#   pic_index: 187 round: 28
#   pic_index: 187 round: 29
#   pic_index: 187 round: 30
#   pic_index: 187 round: 31
#   pic_index: 187 round: 32
#   pic_index: 187 round: 33
#   pic_index: 187 round: 34
#   pic_index: 187 round: 35
#   pic_index: 187 round: 36
#   pic_index: 187 round: 37
#   pic_index: 187 round: 38
#   pic_index: 187 round: 39
#   pic_index: 187 round: 40
#   pic_index: 187 round: 41
#   pic_index: 187 round: 42
#   pic_index: 187 round: 43
#   pic_index: 187 round: 44
#   pic_index: 187 round: 45
#   pic_index: 187 round: 46
#   pic_index: 187 round: 47
#   pic_index: 187 round: 48
#   pic_index: 187 round: 49
#   pic_index: 188 round: 00
#   pic_index: 188 round: 01
#   pic_index: 188 round: 02
#   pic_index: 188 round: 03
#   pic_index: 188 round: 04
#   pic_index: 188 round: 05
#   pic_index: 188 round: 06
#   pic_index: 188 round: 07
#   pic_index: 188 round: 08
#   pic_index: 188 round: 09
#   pic_index: 188 round: 10
#   pic_index: 188 round: 11
#   pic_index: 188 round: 12
#   pic_index: 188 round: 13
#   pic_index: 188 round: 14
#   pic_index: 188 round: 15
#   pic_index: 188 round: 16
#   pic_index: 188 round: 17
#   pic_index: 188 round: 18
#   pic_index: 188 round: 19
#   pic_index: 188 round: 20
#   pic_index: 188 round: 21
#   pic_index: 188 round: 22
#   pic_index: 188 round: 23
#   pic_index: 188 round: 24
#   pic_index: 188 round: 25
#   pic_index: 188 round: 26
#   pic_index: 188 round: 27
#   pic_index: 188 round: 28
#   pic_index: 188 round: 29
#   pic_index: 188 round: 30
#   pic_index: 188 round: 31
#   pic_index: 188 round: 32
#   pic_index: 188 round: 33
#   pic_index: 188 round: 34
#   pic_index: 188 round: 35
#   pic_index: 188 round: 36
#   pic_index: 188 round: 37
#   pic_index: 188 round: 38
#   pic_index: 188 round: 39
#   pic_index: 188 round: 40
#   pic_index: 188 round: 41
#   pic_index: 188 round: 42
#   pic_index: 188 round: 43
#   pic_index: 188 round: 44
#   pic_index: 188 round: 45
#   pic_index: 188 round: 46
#   pic_index: 188 round: 47
#   pic_index: 188 round: 48
#   pic_index: 188 round: 49
#   pic_index: 189 round: 00
#   pic_index: 189 round: 01
#   pic_index: 189 round: 02
#   pic_index: 189 round: 03
#   pic_index: 189 round: 04
#   pic_index: 189 round: 05
#   pic_index: 189 round: 06
#   pic_index: 189 round: 07
#   pic_index: 189 round: 08
#   pic_index: 189 round: 09
#   pic_index: 189 round: 10
#   pic_index: 189 round: 11
#   pic_index: 189 round: 12
#   pic_index: 189 round: 13
#   pic_index: 189 round: 14
#   pic_index: 189 round: 15
#   pic_index: 189 round: 16
#   pic_index: 189 round: 17
#   pic_index: 189 round: 18
#   pic_index: 189 round: 19
#   pic_index: 189 round: 20
#   pic_index: 189 round: 21
#   pic_index: 189 round: 22
#   pic_index: 189 round: 23
#   pic_index: 189 round: 24
#   pic_index: 189 round: 25
#   pic_index: 189 round: 26
#   pic_index: 189 round: 27
#   pic_index: 189 round: 28
#   pic_index: 189 round: 29
#   pic_index: 189 round: 30
#   pic_index: 189 round: 31
#   pic_index: 189 round: 32
#   pic_index: 189 round: 33
#   pic_index: 189 round: 34
#   pic_index: 189 round: 35
#   pic_index: 189 round: 36
#   pic_index: 189 round: 37
#   pic_index: 189 round: 38
#   pic_index: 189 round: 39
#   pic_index: 189 round: 40
#   pic_index: 189 round: 41
#   pic_index: 189 round: 42
#   pic_index: 189 round: 43
#   pic_index: 189 round: 44
#   pic_index: 189 round: 45
#   pic_index: 189 round: 46
#   pic_index: 189 round: 47
#   pic_index: 189 round: 48
#   pic_index: 189 round: 49
#   pic_index: 190 round: 00
#   pic_index: 190 round: 01
#   pic_index: 190 round: 02
#   pic_index: 190 round: 03
#   pic_index: 190 round: 04
#   pic_index: 190 round: 05
#   pic_index: 190 round: 06
#   pic_index: 190 round: 07
#   pic_index: 190 round: 08
#   pic_index: 190 round: 09
#   pic_index: 190 round: 10
#   pic_index: 190 round: 11
#   pic_index: 190 round: 12
#   pic_index: 190 round: 13
#   pic_index: 190 round: 14
#   pic_index: 190 round: 15
#   pic_index: 190 round: 16
#   pic_index: 190 round: 17
#   pic_index: 190 round: 18
#   pic_index: 190 round: 19
#   pic_index: 190 round: 20
#   pic_index: 190 round: 21
#   pic_index: 190 round: 22
#   pic_index: 190 round: 23
#   pic_index: 190 round: 24
#   pic_index: 190 round: 25
#   pic_index: 190 round: 26
#   pic_index: 190 round: 27
#   pic_index: 190 round: 28
#   pic_index: 190 round: 29
#   pic_index: 190 round: 30
#   pic_index: 190 round: 31
#   pic_index: 190 round: 32
#   pic_index: 190 round: 33
#   pic_index: 190 round: 34
#   pic_index: 190 round: 35
#   pic_index: 190 round: 36
#   pic_index: 190 round: 37
#   pic_index: 190 round: 38
#   pic_index: 190 round: 39
#   pic_index: 190 round: 40
#   pic_index: 190 round: 41
#   pic_index: 190 round: 42
#   pic_index: 190 round: 43
#   pic_index: 190 round: 44
#   pic_index: 190 round: 45
#   pic_index: 190 round: 46
#   pic_index: 190 round: 47
#   pic_index: 190 round: 48
#   pic_index: 190 round: 49
#   pic_index: 191 round: 00
#   pic_index: 191 round: 01
#   pic_index: 191 round: 02
#   pic_index: 191 round: 03
#   pic_index: 191 round: 04
#   pic_index: 191 round: 05
#   pic_index: 191 round: 06
#   pic_index: 191 round: 07
#   pic_index: 191 round: 08
#   pic_index: 191 round: 09
#   pic_index: 191 round: 10
#   pic_index: 191 round: 11
#   pic_index: 191 round: 12
#   pic_index: 191 round: 13
#   pic_index: 191 round: 14
#   pic_index: 191 round: 15
#   pic_index: 191 round: 16
#   pic_index: 191 round: 17
#   pic_index: 191 round: 18
#   pic_index: 191 round: 19
#   pic_index: 191 round: 20
#   pic_index: 191 round: 21
#   pic_index: 191 round: 22
#   pic_index: 191 round: 23
#   pic_index: 191 round: 24
#   pic_index: 191 round: 25
#   pic_index: 191 round: 26
#   pic_index: 191 round: 27
#   pic_index: 191 round: 28
#   pic_index: 191 round: 29
#   pic_index: 191 round: 30
#   pic_index: 191 round: 31
#   pic_index: 191 round: 32
#   pic_index: 191 round: 33
#   pic_index: 191 round: 34
#   pic_index: 191 round: 35
#   pic_index: 191 round: 36
#   pic_index: 191 round: 37
#   pic_index: 191 round: 38
#   pic_index: 191 round: 39
#   pic_index: 191 round: 40
#   pic_index: 191 round: 41
#   pic_index: 191 round: 42
#   pic_index: 191 round: 43
#   pic_index: 191 round: 44
#   pic_index: 191 round: 45
#   pic_index: 191 round: 46
#   pic_index: 191 round: 47
#   pic_index: 191 round: 48
#   pic_index: 191 round: 49
#   pic_index: 192 round: 00
#   pic_index: 192 round: 01
#   pic_index: 192 round: 02
#   pic_index: 192 round: 03
#   pic_index: 192 round: 04
#   pic_index: 192 round: 05
#   pic_index: 192 round: 06
#   pic_index: 192 round: 07
#   pic_index: 192 round: 08
#   pic_index: 192 round: 09
#   pic_index: 192 round: 10
#   pic_index: 192 round: 11
#   pic_index: 192 round: 12
#   pic_index: 192 round: 13
#   pic_index: 192 round: 14
#   pic_index: 192 round: 15
#   pic_index: 192 round: 16
#   pic_index: 192 round: 17
#   pic_index: 192 round: 18
#   pic_index: 192 round: 19
#   pic_index: 192 round: 20
#   pic_index: 192 round: 21
#   pic_index: 192 round: 22
#   pic_index: 192 round: 23
#   pic_index: 192 round: 24
#   pic_index: 192 round: 25
#   pic_index: 192 round: 26
#   pic_index: 192 round: 27
#   pic_index: 192 round: 28
#   pic_index: 192 round: 29
#   pic_index: 192 round: 30
#   pic_index: 192 round: 31
#   pic_index: 192 round: 32
#   pic_index: 192 round: 33
#   pic_index: 192 round: 34
#   pic_index: 192 round: 35
#   pic_index: 192 round: 36
#   pic_index: 192 round: 37
#   pic_index: 192 round: 38
#   pic_index: 192 round: 39
#   pic_index: 192 round: 40
#   pic_index: 192 round: 41
#   pic_index: 192 round: 42
#   pic_index: 192 round: 43
#   pic_index: 192 round: 44
#   pic_index: 192 round: 45
#   pic_index: 192 round: 46
#   pic_index: 192 round: 47
#   pic_index: 192 round: 48
#   pic_index: 192 round: 49
#   pic_index: 193 round: 00
#   pic_index: 193 round: 01
#   pic_index: 193 round: 02
#   pic_index: 193 round: 03
#   pic_index: 193 round: 04
#   pic_index: 193 round: 05
#   pic_index: 193 round: 06
#   pic_index: 193 round: 07
#   pic_index: 193 round: 08
#   pic_index: 193 round: 09
#   pic_index: 193 round: 10
#   pic_index: 193 round: 11
#   pic_index: 193 round: 12
#   pic_index: 193 round: 13
#   pic_index: 193 round: 14
#   pic_index: 193 round: 15
#   pic_index: 193 round: 16
#   pic_index: 193 round: 17
#   pic_index: 193 round: 18
#   pic_index: 193 round: 19
#   pic_index: 193 round: 20
#   pic_index: 193 round: 21
#   pic_index: 193 round: 22
#   pic_index: 193 round: 23
#   pic_index: 193 round: 24
#   pic_index: 193 round: 25
#   pic_index: 193 round: 26
#   pic_index: 193 round: 27
#   pic_index: 193 round: 28
#   pic_index: 193 round: 29
#   pic_index: 193 round: 30
#   pic_index: 193 round: 31
#   pic_index: 193 round: 32
#   pic_index: 193 round: 33
#   pic_index: 193 round: 34
#   pic_index: 193 round: 35
#   pic_index: 193 round: 36
#   pic_index: 193 round: 37
#   pic_index: 193 round: 38
#   pic_index: 193 round: 39
#   pic_index: 193 round: 40
#   pic_index: 193 round: 41
#   pic_index: 193 round: 42
#   pic_index: 193 round: 43
#   pic_index: 193 round: 44
#   pic_index: 193 round: 45
#   pic_index: 193 round: 46
#   pic_index: 193 round: 47
#   pic_index: 193 round: 48
#   pic_index: 193 round: 49
#   pic_index: 195 round: 00
#   pic_index: 195 round: 01
#   pic_index: 195 round: 02
#   pic_index: 195 round: 03
#   pic_index: 195 round: 04
#   pic_index: 195 round: 05
#   pic_index: 195 round: 06
#   pic_index: 195 round: 07
#   pic_index: 195 round: 08
#   pic_index: 195 round: 09
#   pic_index: 195 round: 10
#   pic_index: 195 round: 11
#   pic_index: 195 round: 12
#   pic_index: 195 round: 13
#   pic_index: 195 round: 14
#   pic_index: 195 round: 15
#   pic_index: 195 round: 16
#   pic_index: 195 round: 17
#   pic_index: 195 round: 18
#   pic_index: 195 round: 19
#   pic_index: 195 round: 20
#   pic_index: 195 round: 21
#   pic_index: 195 round: 22
#   pic_index: 195 round: 23
#   pic_index: 195 round: 24
#   pic_index: 195 round: 25
#   pic_index: 195 round: 26
#   pic_index: 195 round: 27
#   pic_index: 195 round: 28
#   pic_index: 195 round: 29
#   pic_index: 195 round: 30
#   pic_index: 195 round: 31
#   pic_index: 195 round: 32
#   pic_index: 195 round: 33
#   pic_index: 195 round: 34
#   pic_index: 195 round: 35
#   pic_index: 195 round: 36
#   pic_index: 195 round: 37
#   pic_index: 195 round: 38
#   pic_index: 195 round: 39
#   pic_index: 195 round: 40
#   pic_index: 195 round: 41
#   pic_index: 195 round: 42
#   pic_index: 195 round: 43
#   pic_index: 195 round: 44
#   pic_index: 195 round: 45
#   pic_index: 195 round: 46
#   pic_index: 195 round: 47
#   pic_index: 195 round: 48
#   pic_index: 195 round: 49
#   pic_index: 196 round: 00
#   pic_index: 196 round: 01
#   pic_index: 196 round: 02
#   pic_index: 196 round: 03
#   pic_index: 196 round: 04
#   pic_index: 196 round: 05
#   pic_index: 196 round: 06
#   pic_index: 196 round: 07
#   pic_index: 196 round: 08
#   pic_index: 196 round: 09
#   pic_index: 196 round: 10
#   pic_index: 196 round: 11
#   pic_index: 196 round: 12
#   pic_index: 196 round: 13
#   pic_index: 196 round: 14
#   pic_index: 196 round: 15
#   pic_index: 196 round: 16
#   pic_index: 196 round: 17
#   pic_index: 196 round: 18
#   pic_index: 196 round: 19
#   pic_index: 196 round: 20
#   pic_index: 196 round: 21
#   pic_index: 196 round: 22
#   pic_index: 196 round: 23
#   pic_index: 196 round: 24
#   pic_index: 196 round: 25
#   pic_index: 196 round: 26
#   pic_index: 196 round: 27
#   pic_index: 196 round: 28
#   pic_index: 196 round: 29
#   pic_index: 196 round: 30
#   pic_index: 196 round: 31
#   pic_index: 196 round: 32
#   pic_index: 196 round: 33
#   pic_index: 196 round: 34
#   pic_index: 196 round: 35
#   pic_index: 196 round: 36
#   pic_index: 196 round: 37
#   pic_index: 196 round: 38
#   pic_index: 196 round: 39
#   pic_index: 196 round: 40
#   pic_index: 196 round: 41
#   pic_index: 196 round: 42
#   pic_index: 196 round: 43
#   pic_index: 196 round: 44
#   pic_index: 196 round: 45
#   pic_index: 196 round: 46
#   pic_index: 196 round: 47
#   pic_index: 196 round: 48
#   pic_index: 196 round: 49
#   pic_index: 197 round: 00
#   pic_index: 197 round: 01
#   pic_index: 197 round: 02
#   pic_index: 197 round: 03
#   pic_index: 197 round: 04
#   pic_index: 197 round: 05
#   pic_index: 197 round: 06
#   pic_index: 197 round: 07
#   pic_index: 197 round: 08
#   pic_index: 197 round: 09
#   pic_index: 197 round: 10
#   pic_index: 197 round: 11
#   pic_index: 197 round: 12
#   pic_index: 197 round: 13
#   pic_index: 197 round: 14
#   pic_index: 197 round: 15
#   pic_index: 197 round: 16
#   pic_index: 197 round: 17
#   pic_index: 197 round: 18
#   pic_index: 197 round: 19
#   pic_index: 197 round: 20
#   pic_index: 197 round: 21
#   pic_index: 197 round: 22
#   pic_index: 197 round: 23
#   pic_index: 197 round: 24
#   pic_index: 197 round: 25
#   pic_index: 197 round: 26
#   pic_index: 197 round: 27
#   pic_index: 197 round: 28
#   pic_index: 197 round: 29
#   pic_index: 197 round: 30
#   pic_index: 197 round: 31
#   pic_index: 197 round: 32
#   pic_index: 197 round: 33
#   pic_index: 197 round: 34
#   pic_index: 197 round: 35
#   pic_index: 197 round: 36
#   pic_index: 197 round: 37
#   pic_index: 197 round: 38
#   pic_index: 197 round: 39
#   pic_index: 197 round: 40
#   pic_index: 197 round: 41
#   pic_index: 197 round: 42
#   pic_index: 197 round: 43
#   pic_index: 197 round: 44
#   pic_index: 197 round: 45
#   pic_index: 197 round: 46
#   pic_index: 197 round: 47
#   pic_index: 197 round: 48
#   pic_index: 197 round: 49
#   pic_index: 198 round: 00
#   pic_index: 198 round: 01
#   pic_index: 198 round: 02
#   pic_index: 198 round: 03
#   pic_index: 198 round: 04
#   pic_index: 198 round: 05
#   pic_index: 198 round: 06
#   pic_index: 198 round: 07
#   pic_index: 198 round: 08
#   pic_index: 198 round: 09
#   pic_index: 198 round: 10
#   pic_index: 198 round: 11
#   pic_index: 198 round: 12
#   pic_index: 198 round: 13
#   pic_index: 198 round: 14
#   pic_index: 198 round: 15
#   pic_index: 198 round: 16
#   pic_index: 198 round: 17
#   pic_index: 198 round: 18
#   pic_index: 198 round: 19
#   pic_index: 198 round: 20
#   pic_index: 198 round: 21
#   pic_index: 198 round: 22
#   pic_index: 198 round: 23
#   pic_index: 198 round: 24
#   pic_index: 198 round: 25
#   pic_index: 198 round: 26
#   pic_index: 198 round: 27
#   pic_index: 198 round: 28
#   pic_index: 198 round: 29
#   pic_index: 198 round: 30
#   pic_index: 198 round: 31
#   pic_index: 198 round: 32
#   pic_index: 198 round: 33
#   pic_index: 198 round: 34
#   pic_index: 198 round: 35
#   pic_index: 198 round: 36
#   pic_index: 198 round: 37
#   pic_index: 198 round: 38
#   pic_index: 198 round: 39
#   pic_index: 198 round: 40
#   pic_index: 198 round: 41
#   pic_index: 198 round: 42
#   pic_index: 198 round: 43
#   pic_index: 198 round: 44
#   pic_index: 198 round: 45
#   pic_index: 198 round: 46
#   pic_index: 198 round: 47
#   pic_index: 198 round: 48
#   pic_index: 198 round: 49
#   pic_index: 199 round: 00
#   pic_index: 199 round: 01
#   pic_index: 199 round: 02
#   pic_index: 199 round: 03
#   pic_index: 199 round: 04
#   pic_index: 199 round: 05
#   pic_index: 199 round: 06
#   pic_index: 199 round: 07
#   pic_index: 199 round: 08
#   pic_index: 199 round: 09
#   pic_index: 199 round: 10
#   pic_index: 199 round: 11
#   pic_index: 199 round: 12
#   pic_index: 199 round: 13
#   pic_index: 199 round: 14
#   pic_index: 199 round: 15
#   pic_index: 199 round: 16
#   pic_index: 199 round: 17
#   pic_index: 199 round: 18
#   pic_index: 199 round: 19
#   pic_index: 199 round: 20
#   pic_index: 199 round: 21
#   pic_index: 199 round: 22
#   pic_index: 199 round: 23
#   pic_index: 199 round: 24
#   pic_index: 199 round: 25
#   pic_index: 199 round: 26
#   pic_index: 199 round: 27
#   pic_index: 199 round: 28
#   pic_index: 199 round: 29
#   pic_index: 199 round: 30
#   pic_index: 199 round: 31
#   pic_index: 199 round: 32
#   pic_index: 199 round: 33
#   pic_index: 199 round: 34
#   pic_index: 199 round: 35
#   pic_index: 199 round: 36
#   pic_index: 199 round: 37
#   pic_index: 199 round: 38
#   pic_index: 199 round: 39
#   pic_index: 199 round: 40
#   pic_index: 199 round: 41
#   pic_index: 199 round: 42
#   pic_index: 199 round: 43
#   pic_index: 199 round: 44
#   pic_index: 199 round: 45
#   pic_index: 199 round: 46
#   pic_index: 199 round: 47
#   pic_index: 199 round: 48
#   pic_index: 199 round: 49

# %%
layer_stats_df.to_csv(f'{model_info}_model_random_paths_for_{classes[the_class]}_and_{K_ROUND}_Rounds.csv', index=False)

# %%
layer_stats_df = pd.read_csv(f'{model_info}_model_random_paths_for_{classes[the_class]}_and_{K_ROUND}_Rounds.csv')
# Create violin plot
sns.violinplot(data=layer_stats_df, 
                x='layer_name', 
                y='mean_cross_model_difference',
                inner='quartile',
                density_norm='count')
# density_norm{“area”, “count”, “width”}
# Method that normalizes each density to determine the violin’s width. 
# If area, each violin will have the same area. If count, 
# the width will be proportional to the number of observations. 
# If width, each violin will have the same width.

# Customize plot
plt.xticks(rotation=45, ha='right')
plt.title(f'Distribution of Differences Between Models For {classes[the_class]}')
plt.xlabel('Layer')
plt.ylabel('Difference')
#plt.yscale('log')
plt.ylim(0, 1e1)

# Adjust layout
plt.tight_layout()

# Save plot
save_path = f'{model_info}_model_differences_violin_plot_for_{classes[the_class]}.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
plt.show()
print("Minimum values for each layer:")
for layer in layer_stats_df['layer_name'].unique():
    min_value = layer_stats_df[layer_stats_df['layer_name'] == layer]['mean_cross_model_difference'].min()
    print(f"{layer}: {min_value:.6e}")
# Out:
# Minimum values for each layer:
# features.0: 2.890825e-06
# features.4: 1.354888e-05
# features.8: 0.000000e+00
# classifier.1: 1.293235e-04
# classifier.4: 5.197644e-03

# %%
cat_df = pd.read_csv(f'{model_info}_model_random_paths_for_cat_and_{K_ROUND}_Rounds.csv')
dog_df = pd.read_csv(f'{model_info}_model_random_paths_for_dog_and_{K_ROUND}_Rounds.csv')

cat_df['class'] = 'cat'
dog_df['class'] = 'dog'

combined_df = pd.concat([cat_df, dog_df], ignore_index=True)

plt.figure(figsize=(14, 8))
sns.violinplot(data=combined_df, 
               x='layer_name', 
               y='mean_cross_model_difference',
               hue='class',
               inner='quartile',
               density_norm='count',
               split=True,
               palette={'cat': 'red', 'dog': 'blue'})

plt.xticks(rotation=45, ha='right')
plt.title(f'Distribution of Differences Between {model_info} Models: Cat vs Dog')
plt.xlabel('Layer')
plt.ylabel('Difference')
plt.ylim(0, 1e1)
plt.legend(title='Class')
plt.tight_layout()

save_path = f'{model_info}_model_differences_violin_plot_cat_vs_dog_{K_ROUND}_rounds.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
plt.show()
print("Minimum values for each layer:")
for layer in combined_df['layer_name'].unique():
    min_value = combined_df[combined_df['layer_name'] == layer]['mean_cross_model_difference'].min()
    print(f"{layer}: {min_value:.6e}")
# Out:
# Minimum values for each layer:
# conv1: 0.000000e+00
# layer1.0.conv1: 4.768372e-07
# layer1.0.conv2: 2.777576e-05
# layer1.1.conv1: 3.802776e-05
# layer1.1.conv2: 2.130866e-06
# layer2.0.conv1: 0.000000e+00
# layer2.0.conv2: 0.000000e+00
# layer2.0.downsample.0: 1.564622e-05
# layer2.1.conv1: 0.000000e+00
# layer2.1.conv2: 4.000962e-06
# layer3.0.conv1: 6.625056e-05
# layer3.0.conv2: 3.886223e-05
# layer3.0.downsample.0: 8.728355e-06
# layer3.1.conv1: 0.000000e+00
# layer3.1.conv2: 7.078052e-07
# layer4.0.conv1: 1.943856e-05
# layer4.0.conv2: 0.000000e+00
# layer4.0.downsample.0: 2.674758e-06
# layer4.1.conv1: 1.281500e-05
# layer4.1.conv2: 6.156741e-06
# fc: 5.288959e-03
